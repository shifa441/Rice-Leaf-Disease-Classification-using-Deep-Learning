# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150555.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_145527.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_144634.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_155701.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_154546.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_161614.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150917.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_152001.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_155923.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_152354.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_160709.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150912.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_161917.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_150427.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_160749.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_155003.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150737.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_152018.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150540.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_154145.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_160200.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_143323 - Copy.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_152745.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_151608.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_152732.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_155939.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_152033.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_143323.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_160215.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_161747.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_161236.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150537.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_160946.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_162404.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_161758.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_150058.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_145106.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_154257.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241031_161612.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_152405.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_152556.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_145329.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150732.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_154224.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_153905.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_153934.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_154316.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_161626.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_162342.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_160533.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_160917.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_160630.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_160430.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150444.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_153625.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_144021.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_151203.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150709.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_152632.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_160145.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_150651.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_152007.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_152713.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_152021.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_161011.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150459.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_150446.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_144121.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_154325.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150725.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_152010.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_152052.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150723.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_152107.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150545.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_154222.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_161104.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150527.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_160236.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_151655.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150728.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_160056.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_155854.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_151006.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_155443.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_145845.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_155619.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_160315.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_152343.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_160641.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_155907.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_162608.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150546.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150730.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_161909.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_155339.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_160011.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_145654.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_153453.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_154231.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150553.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_160041.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150900.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_161445.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_154214.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150549.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_151503.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_152018.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_161133.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_152625.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_160457.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_150722.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_161725.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150538.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_151958.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150718.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_161414.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_161843.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_162439.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_153818.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_145405.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_160025.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_144130.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_161221.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150712.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150525.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_152038.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_154126.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_161817.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_154229.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_144721.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_154225.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150714.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_153042.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_150111.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_162151.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150550.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_143547.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_152015.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_155600.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_160257.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150535.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_154813.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_162131.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_160326.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_162334.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150904.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_152012.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_154150.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150734.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150736.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_155305.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150717.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_151656.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150905.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150557.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_152034.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_152037.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150914.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241031_161648.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_153756.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_144857.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150902.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_154616.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_162626.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_143503.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_152904.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_143503 - Copy.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_154221.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_144032.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_162616.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_150857.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_150030.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_161259.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150733.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_161828.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150541.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_154220.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_152004.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_162142.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_160048.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_154628.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_162202.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150445.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_145241.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_160404.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_154228.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_153651.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_151524.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_161714.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150548.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_153445.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_152016.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_145943.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_152545.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_152025.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_154226.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_160545.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_155426.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_144239.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_151638.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150722.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_151016.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_150509.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_163309.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_154227.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_155505.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_155652.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_154420.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_155532.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150916.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_161937.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_162059.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_155256.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_145258.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_155028.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_144709.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_161040.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_152106.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_162350.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_153603.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_160610.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_152035.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_155637.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_151950.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_150844.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241031_161629.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_154745.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_154133.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_154127.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_162649.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_162000.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_162244.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150406.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_145710.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150534.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_162636.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_150933.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150724.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_161341.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_154557.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_153402.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_162219.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_161247.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_152039.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_145625.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150443.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150542.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_145229.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150500.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_160739.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_162233.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_153136.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_143947.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_150227.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_144251.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_161157.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_161112.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_151039.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_155323.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_144042.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_152718.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_161432.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150735.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_155126.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_144620.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_161505.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150715.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_145754.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_154223.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_160517.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_161212.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_154916.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_161053.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_163500.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_151859.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_154124.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_151030.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150530.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150556.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_150327_Bokeh.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_161332.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150408.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_155835.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_155406.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_154023.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_155203.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_162522.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_161457.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_155455.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_152024.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_160439.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_152029.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_160955.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_160727.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/20241114_150918.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241114_154936.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/orginal/IMG_20241031_165122.jpg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_825.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_6253.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_910.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_2794.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_6466.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_9619.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_808.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_1276.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_3569.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_8901.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_6794.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_7101.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_8505.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_4281.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_5590.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_8471.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_2998.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_4374.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_2652.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_4028.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_7363.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_4156.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_2944.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_8696.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_1823.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_469.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_7590.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_5258.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_9002.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_9020.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_5588.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_539.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_9760.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_3555.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_4588.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_4632.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_1877.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_308.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_1939.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_1964.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_1009.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_9809.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_1237.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_4268.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_1290.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_7069.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_5535.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_7120.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_4432.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_6941.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_599.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_4314.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_642.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_1108.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_620.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_4816.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_8016.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_1696.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_250.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_2847.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_2562.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_6367.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_7094.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_1596.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_9608.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_2659.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_546.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_5076.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_1379.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_1677.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_9617.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_5245.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_3472.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_6126.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_6647.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_5780.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_6512.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_7065.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_8968.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_459.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_7812.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_1707.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_3365.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_1176.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_7011.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_9912.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_6720.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_4175.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_8754.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_3605.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_9874.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_9699.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_4563.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_9873.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_8485.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_8496.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_6772.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_8529.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_2816.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_9500.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_1213.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_3658.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_4344.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_8536.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_2786.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_2785.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_7055.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_8488.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_5011.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_1847.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_6177.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_9742.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Tungro/augmented/Aug Tungro/aug_0_7468.jpeg
# ...
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_6798.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_9339.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_352.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_3129.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_5912.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_4007.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_542.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_7762.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_5450.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_5843.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_7056.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_9486.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_7880.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_8760.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_2555.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_2221.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_1608.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_5519.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_1426.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_222.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_7213.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_2426.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_389.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_963.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_4371.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_8128.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_9901.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_4264.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_6088.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_1547.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_4325.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_1553.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_6644.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_1172.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_7345.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_7826.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_4421.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_1583.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_779.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_7031.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_3405.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_7178.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_851.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_8296.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_6321.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_7996.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_7098.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_1949.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_1997.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_2610.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_7704.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_8165.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_1752.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_484.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_7549.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_2149.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_1039.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_1522.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_2315.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_2147.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_3585.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_7092.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_7232.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_5173.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_2058.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_2692.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_2131.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_7750.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_5415.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_8146.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_1740.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_4610.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_5460.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_3634.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_5260.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_7099.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_415.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_3362.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_3507.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_5434.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_2615.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_4169.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_6407.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_9508.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_9330.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_5024.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_3798.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_3420.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_608.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_9123.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_7302.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_3715.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_2910.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_6831.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_8195.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_2950.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_4993.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_9531.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_3350.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_7650.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_7135.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_6428.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_6116.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_3568.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_7210.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_7279.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_4606.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_9325.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_1401.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_694.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_9773.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_1506.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_428.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_4903.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_5250.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_9732.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_5633.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_4144.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_7440.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_4929.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_6010.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_7348.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_9678.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_6495.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_2267.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_9360.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_2319.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_6210.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_6763.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_1574.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_7528.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_9404.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_2725.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_9810.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_780.jpeg
# /kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset/Rice/augmented/Aug Rice/aug_0_8212.jpeg

# %%
# ── Cell 1 — Install packages ────────────────────────────────
# !pip install -q grad-cam timm tqdm

# %%
# ── Cell 2 — Imports + Seed ──────────────────────────────────
import os
import time
import random
import shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

import torch
import torch.nn as nn
import torch.optim as optim
import timm

from tqdm import tqdm

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils.class_weight import compute_class_weight

from torchvision import datasets, transforms, models
from torchvision.models import (
    MobileNet_V3_Small_Weights,
    EfficientNet_B0_Weights,
    ResNet18_Weights,
    DenseNet121_Weights
)
from torch.utils.data import DataLoader, Subset, WeightedRandomSampler

from pytorch_grad_cam import GradCAM
from pytorch_grad_cam.utils.image import show_cam_on_image
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)

# %%
for root, dirs, files in os.walk('/kaggle/input/datasets'):
    print(root)

# %%
# ── Cell 3 — Device + Paths ──────────────────────────────────
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Device:", device)
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

BASE_PATH = "/kaggle/input/datasets/tasminarahmanshifa/rice-leaf-and-crop-disease-dataset"
DATASET   = BASE_PATH
FILTERED  = "/kaggle/working/filtered_dataset"
OUT_DIR   = "/kaggle/working/paper_outputs"

os.makedirs(OUT_DIR, exist_ok=True)
os.makedirs(os.path.join(OUT_DIR, "plots"),       exist_ok=True)
os.makedirs(os.path.join(OUT_DIR, "gradcam"),     exist_ok=True)
os.makedirs(os.path.join(OUT_DIR, "checkpoints"), exist_ok=True)

print("\n--- DATASET ---")
print(os.listdir(DATASET))
# Out:
# Device: cuda
# GPU: Tesla T4
#
# --- DATASET ---
# ['Tungro', 'Rice Blast', 'Healthy _leaf', 'Bacterial Leaf Blight', 'Rice']

# %%
# ── Cell 4 — Config ──────────────────────────────────────────
BATCH_SIZE           = 16
CNN_EPOCHS           = 20
DL_EPOCHS            = 20
TRANSFORMER_EPOCHS   = 25

print(f"Batch: {BATCH_SIZE} | CNN: {CNN_EPOCHS} | DL: {DL_EPOCHS} | Transformer: {TRANSFORMER_EPOCHS}")
# Out:
# Batch: 16 | CNN: 20 | DL: 20 | Transformer: 25

# %%
# ── Cell 5 — Dataset Filtering ───────────────────────────────
classes_keep = [
    "Bacterial Leaf Blight",
    "Rice Blast",
    "Tungro",
    "Healthy _leaf"
]

if os.path.exists(FILTERED):
    shutil.rmtree(FILTERED)
os.makedirs(FILTERED, exist_ok=True)

for c in classes_keep:
    src = os.path.join(DATASET, c)
    dst = os.path.join(FILTERED, c)
    if os.path.exists(src):
        shutil.copytree(src, dst, dirs_exist_ok=True)
        print(f"Copied: {c}")
    else:
        print(f"Missing: {src}")

print("\nFiltered dataset ready.")

from pathlib import Path

total  = 0
counts = {}

for cls in classes_keep:
    cls_path = Path(FILTERED) / cls
    imgs = (list(cls_path.rglob("*.jpg")) +
            list(cls_path.rglob("*.png")) +
            list(cls_path.rglob("*.jpeg")))
    counts[cls] = len(imgs)
    total += len(imgs)
    print(f"  {cls:<25} → {len(imgs):>5} images")

print(f"\n  {'TOTAL':<25} → {total:>5} images")

ratio = counts[max(counts, key=counts.get)] / counts[min(counts, key=counts.get)]
print(f"\n  Imbalance ratio: {ratio:.2f}x")
# Out:
# Copied: Bacterial Leaf Blight
# Copied: Rice Blast
# Copied: Tungro
# Copied: Healthy _leaf
#
# Filtered dataset ready.
#   Bacterial Leaf Blight     →   978 images
#   Rice Blast                →  3343 images
#   Tungro                    →  3745 images
#   Healthy _leaf             →  1372 images
#
#   TOTAL                     →  9438 images
#
#   Imbalance ratio: 3.83x

# %%
# ── Cell 6 — Transforms ──────────────────────────────────────
train_tf = transforms.Compose([
    transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.RandomRotation(15),
    transforms.ColorJitter(brightness=0.2, contrast=0.2,
                           saturation=0.1, hue=0.05),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

test_tf = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

# %%
# ── Cell 7 — Stratified Split ────────────────────────────────
dataset_full = datasets.ImageFolder(FILTERED, transform=train_tf)
targets  = np.array(dataset_full.targets)
indices  = np.arange(len(targets))




train_idx, temp_idx = train_test_split(
    indices, test_size=0.2, stratify=targets, random_state=42
)
temp_targets = targets[temp_idx]
val_idx, test_idx = train_test_split(
    temp_idx, test_size=0.5, stratify=temp_targets, random_state=42
)

train_dataset = datasets.ImageFolder(FILTERED, transform=train_tf)
val_dataset   = datasets.ImageFolder(FILTERED, transform=test_tf)
test_dataset  = datasets.ImageFolder(FILTERED, transform=test_tf)

train_ds = Subset(train_dataset, train_idx)
val_ds   = Subset(val_dataset,   val_idx)
test_ds  = Subset(test_dataset,  test_idx)

class_names = train_dataset.classes
num_classes = len(class_names)

print("Classes:", class_names)
print(f"Train: {len(train_ds)} | Val: {len(val_ds)} | Test: {len(test_ds)}")
# Out:
# Classes: ['Bacterial Leaf Blight', 'Healthy _leaf', 'Rice Blast', 'Tungro']
# Train: 7550 | Val: 944 | Test: 944

# %%
# ── Cell 8 — DataLoaders + Class Weights + Sampler ───────────
train_targets = np.array([train_dataset.targets[i] for i in train_idx])
class_weights = compute_class_weight(
    class_weight="balanced",
    classes=np.unique(train_targets),
    y=train_targets
)
class_weights_tensor = torch.tensor(class_weights, dtype=torch.float).to(device)
print("Class weights:", class_weights_tensor)

sample_weights = torch.tensor(
    [class_weights[t] for t in train_targets], dtype=torch.float
)
sampler = WeightedRandomSampler(
    weights=sample_weights,
    num_samples=len(sample_weights),
    replacement=True
)

train_loader = DataLoader(
    train_ds, batch_size=BATCH_SIZE,
    sampler=sampler,
    num_workers=2,
    pin_memory=(device == "cuda")
)
val_loader = DataLoader(
    val_ds, batch_size=BATCH_SIZE, shuffle=False,
    num_workers=2, pin_memory=(device == "cuda")
)
test_loader = DataLoader(
    test_ds, batch_size=BATCH_SIZE, shuffle=False,
    num_workers=2, pin_memory=(device == "cuda")
)

# Verify balance
sampled_labels = []
for i, (_, y) in enumerate(train_loader):
    sampled_labels.extend(y.numpy().tolist())
    if i >= 200:
        break
c = Counter(sampled_labels)
total_s = sum(c.values())
print("\nSampled distribution:")
for i, cls in enumerate(class_names):
    print(f"  {cls:<25} -> {c[i]} ({c[i]/total_s:.3f})")
# Out:
# Class weights: tensor([2.4137, 1.7190, 0.7059, 0.6300], device='cuda:0')
#
# Sampled distribution:
#   Bacterial Leaf Blight     -> 798 (0.248)
#   Healthy _leaf             -> 785 (0.244)
#   Rice Blast                -> 822 (0.256)
#   Tungro                    -> 811 (0.252)

# %%
# ── Cell 9 — Shared Functions ────────────────────────────────
def train_model(model, train_loader, val_loader, class_weights_tensor, device,
                epochs=15, lr=3e-4, weight_decay=0.0,
                checkpoint_path="/kaggle/working/model_best.pth",
                optimizer_type="adam", scheduler_type=None,
                model_name="Model"):

    model.to(device)
    loss_fn = nn.CrossEntropyLoss(
    weight=class_weights_tensor,
    label_smoothing=0.1
)

    if optimizer_type == "adamw":
        optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
    else:
        optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)

    scheduler = None
    if scheduler_type == "cosine":
        scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)

    best_val_acc = 0.0
    train_losses, val_losses = [], []

    print(f"\n{'='*55}")
    print(f"  Training: {model_name}")
    print(f"{'='*55}")

    for epoch in range(epochs):
        model.train()
        running_loss = 0.0
        train_correct, train_total = 0, 0

        train_bar = tqdm(train_loader, desc=f"Epoch {epoch+1:02d}/{epochs} [Train]",
                         leave=False, ncols=80, position=0)

        for x, y in train_bar:
            x, y = x.to(device), y.to(device)
            optimizer.zero_grad()
            out = model(x)
            if out.dim() == 4:
                out = out.mean(dim=[2, 3])
            if out.dim() != 2:
                out = out.view(out.size(0), -1)
            loss = loss_fn(out, y)
            loss.backward()
            if optimizer_type == "adamw":
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()
            running_loss += loss.item()
            train_correct += (out.argmax(1) == y).sum().item()
            train_total   += y.size(0)
            train_bar.set_postfix(loss=f"{loss.item():.4f}")

        epoch_loss = running_loss / len(train_loader)
        train_acc  = train_correct / train_total
        train_losses.append(epoch_loss)

        model.eval()
        correct, total = 0, 0
        val_running_loss = 0.0

        with torch.no_grad():
            for x, y in val_loader:
                x, y = x.to(device), y.to(device)
                out = model(x)
                if out.dim() == 4:
                    out = out.mean(dim=[2, 3])
                if out.dim() != 2:
                    out = out.view(out.size(0), -1)
                val_running_loss += loss_fn(out, y).item()
                correct += (out.argmax(1) == y).sum().item()
                total   += y.size(0)

        val_acc  = correct / total
        val_loss = val_running_loss / len(val_loader)
        val_losses.append(val_loss)

        if scheduler is not None:
            scheduler.step()

        improved = "✅" if val_acc > best_val_acc else "  "
        print(f"  Epoch {epoch+1:02d}/{epochs} | "
              f"Train Loss: {epoch_loss:.4f} | Train Acc: {train_acc:.4f} | "
              f"Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f} {improved}")

        if val_acc > best_val_acc:
            best_val_acc = val_acc
            torch.save(model.state_dict(), checkpoint_path)

    print(f"\n  Best Val Acc: {best_val_acc:.4f} — saved to {checkpoint_path}")
    model.load_state_dict(torch.load(checkpoint_path, map_location=device))
    return model, train_losses, val_losses


def evaluate(model, loader, class_names, device):
    model.eval()
    all_preds, all_labels = [], []
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device)
            out = model(x)
            if out.dim() == 4:
                out = out.mean(dim=[2, 3])
            if out.dim() != 2:
                out = out.view(out.size(0), -1)
            all_preds.extend(out.argmax(1).cpu().numpy())
            all_labels.extend(y.numpy())

    report = classification_report(
        all_labels, all_preds,
        target_names=class_names,
        output_dict=True,
        zero_division=0
    )
    cm = confusion_matrix(all_labels, all_preds)
    return all_labels, all_preds, report, cm


def model_info(model, device):
    model.eval()
    params  = sum(p.numel() for p in model.parameters())
    size_mb = params * 4 / (1024 ** 2)
    x = torch.randn(1, 3, 224, 224).to(device)

    with torch.inference_mode():
        for _ in range(10):
            _ = model(x)
        if device == "cuda":
            torch.cuda.synchronize()
        start = time.perf_counter()
        for _ in range(100):
            _ = model(x)
        if device == "cuda":
            torch.cuda.synchronize()
        elapsed = time.perf_counter() - start

    latency = elapsed / 100
    fps     = 1 / latency
    return params, size_mb, latency, fps

# %%
model_mobilenet = models.mobilenet_v3_small(weights=MobileNet_V3_Small_Weights.DEFAULT)
model_mobilenet.classifier[3] = nn.Linear(
    model_mobilenet.classifier[3].in_features, num_classes
)
model_mobilenet, mobilenet_train_losses, mobilenet_val_losses = train_model(
    model_mobilenet, train_loader, val_loader,
    class_weights_tensor, device,
    epochs=CNN_EPOCHS,
    lr=3e-4,
    weight_decay=0.01,
    optimizer_type="adamw",
    scheduler_type="cosine",
    checkpoint_path=os.path.join(OUT_DIR, "checkpoints", "mobilenet_best.pth"),
    model_name="MobileNetV3-Small"
)
# Out:
# =======================================================
#   Training: MobileNetV3-Small
# =======================================================
#   Epoch 01/20 | Train Loss: 0.7641 | Train Acc: 0.6224 | Val Loss: 0.8878 | Val Acc: 0.7013 ✅
#   Epoch 02/20 | Train Loss: 0.6217 | Train Acc: 0.7612 | Val Loss: 0.9413 | Val Acc: 0.6155
#   Epoch 03/20 | Train Loss: 0.5650 | Train Acc: 0.8207 | Val Loss: 0.7824 | Val Acc: 0.8061 ✅
#   Epoch 04/20 | Train Loss: 0.5234 | Train Acc: 0.8540 | Val Loss: 0.6926 | Val Acc: 0.8686 ✅
#   Epoch 05/20 | Train Loss: 0.4963 | Train Acc: 0.8840 | Val Loss: 0.6985 | Val Acc: 0.8729 ✅
#   Epoch 06/20 | Train Loss: 0.4800 | Train Acc: 0.8944 | Val Loss: 0.7837 | Val Acc: 0.7977
#   Epoch 07/20 | Train Loss: 0.4672 | Train Acc: 0.9044 | Val Loss: 0.7960 | Val Acc: 0.7627
#   Epoch 08/20 | Train Loss: 0.4607 | Train Acc: 0.9099 | Val Loss: 0.6560 | Val Acc: 0.8877 ✅
#   Epoch 09/20 | Train Loss: 0.4432 | Train Acc: 0.9216 | Val Loss: 0.6526 | Val Acc: 0.8919 ✅
#   Epoch 10/20 | Train Loss: 0.4290 | Train Acc: 0.9287 | Val Loss: 0.6474 | Val Acc: 0.8941 ✅
#   Epoch 11/20 | Train Loss: 0.4295 | Train Acc: 0.9325 | Val Loss: 0.6560 | Val Acc: 0.8803
#   Epoch 12/20 | Train Loss: 0.4223 | Train Acc: 0.9358 | Val Loss: 0.6418 | Val Acc: 0.9100 ✅
#   Epoch 13/20 | Train Loss: 0.4220 | Train Acc: 0.9403 | Val Loss: 0.6214 | Val Acc: 0.9142 ✅
#   Epoch 14/20 | Train Loss: 0.4164 | Train Acc: 0.9460 | Val Loss: 0.6261 | Val Acc: 0.9153 ✅
#   Epoch 15/20 | Train Loss: 0.4079 | Train Acc: 0.9494 | Val Loss: 0.6343 | Val Acc: 0.9100
#   Epoch 16/20 | Train Loss: 0.4065 | Train Acc: 0.9479 | Val Loss: 0.6254 | Val Acc: 0.9174 ✅
#   Epoch 17/20 | Train Loss: 0.4063 | Train Acc: 0.9498 | Val Loss: 0.6265 | Val Acc: 0.9184 ✅
#   Epoch 18/20 | Train Loss: 0.4046 | Train Acc: 0.9482 | Val Loss: 0.6198 | Val Acc: 0.9216 ✅
#   Epoch 19/20 | Train Loss: 0.3984 | Train Acc: 0.9483 | Val Loss: 0.6235 | Val Acc: 0.9206
#   Epoch 20/20 | Train Loss: 0.3937 | Train Acc: 0.9528 | Val Loss: 0.6251 | Val Acc: 0.9184
#
#   Best Val Acc: 0.9216 — saved to /kaggle/working/paper_outputs/checkpoints/mobilenet_best.pth

# %%
# ── Cell 11 — Train CNN: EfficientNetB0 ──────────────────────
model_eff = models.efficientnet_b0(weights=EfficientNet_B0_Weights.DEFAULT)
model_eff.classifier[1] = nn.Linear(
    model_eff.classifier[1].in_features, num_classes
)
model_eff, eff_train_losses, eff_val_losses = train_model(
    model_eff, train_loader, val_loader,
    class_weights_tensor, device,
    epochs=CNN_EPOCHS,
    lr=3e-4,
    weight_decay=0.01,
    optimizer_type="adamw",
    scheduler_type="cosine",
    checkpoint_path=os.path.join(OUT_DIR, "checkpoints", "efficientnet_best.pth"),
    model_name="EfficientNetB0"
)
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 141MB/s]
# =======================================================
#   Training: EfficientNetB0
# =======================================================
#   Epoch 01/20 | Train Loss: 0.7347 | Train Acc: 0.6609 | Val Loss: 0.8378 | Val Acc: 0.7458 ✅
#   Epoch 02/20 | Train Loss: 0.5902 | Train Acc: 0.7911 | Val Loss: 0.7506 | Val Acc: 0.8453 ✅
#   Epoch 03/20 | Train Loss: 0.5443 | Train Acc: 0.8419 | Val Loss: 0.7067 | Val Acc: 0.8750 ✅
#   Epoch 04/20 | Train Loss: 0.4938 | Train Acc: 0.8824 | Val Loss: 0.6976 | Val Acc: 0.8814 ✅
#   Epoch 05/20 | Train Loss: 0.4786 | Train Acc: 0.9008 | Val Loss: 0.6806 | Val Acc: 0.8856 ✅
#   Epoch 06/20 | Train Loss: 0.4542 | Train Acc: 0.9138 | Val Loss: 0.6832 | Val Acc: 0.8962 ✅
#   Epoch 07/20 | Train Loss: 0.4526 | Train Acc: 0.9228 | Val Loss: 0.6371 | Val Acc: 0.9057 ✅
#   Epoch 08/20 | Train Loss: 0.4417 | Train Acc: 0.9302 | Val Loss: 0.6487 | Val Acc: 0.9110 ✅
#   Epoch 09/20 | Train Loss: 0.4343 | Train Acc: 0.9348 | Val Loss: 0.6246 | Val Acc: 0.9089
#   Epoch 10/20 | Train Loss: 0.4189 | Train Acc: 0.9423 | Val Loss: 0.6348 | Val Acc: 0.9100
#   Epoch 11/20 | Train Loss: 0.4086 | Train Acc: 0.9486 | Val Loss: 0.6331 | Val Acc: 0.9163 ✅
#   Epoch 12/20 | Train Loss: 0.4001 | Train Acc: 0.9517 | Val Loss: 0.6314 | Val Acc: 0.9163
#   Epoch 13/20 | Train Loss: 0.3966 | Train Acc: 0.9518 | Val Loss: 0.6461 | Val Acc: 0.9142
#   Epoch 14/20 | Train Loss: 0.3930 | Train Acc: 0.9546 | Val Loss: 0.6221 | Val Acc: 0.9248 ✅
#   Epoch 15/20 | Train Loss: 0.3953 | Train Acc: 0.9548 | Val Loss: 0.6312 | Val Acc: 0.9142
#   Epoch 16/20 | Train Loss: 0.3830 | Train Acc: 0.9638 | Val Loss: 0.6251 | Val Acc: 0.9184
#   Epoch 17/20 | Train Loss: 0.3881 | Train Acc: 0.9577 | Val Loss: 0.6148 | Val Acc: 0.9237
#   Epoch 18/20 | Train Loss: 0.3790 | Train Acc: 0.9626 | Val Loss: 0.6186 | Val Acc: 0.9216
#   Epoch 19/20 | Train Loss: 0.3784 | Train Acc: 0.9672 | Val Loss: 0.6242 | Val Acc: 0.9174
#   Epoch 20/20 | Train Loss: 0.3806 | Train Acc: 0.9636 | Val Loss: 0.6269 | Val Acc: 0.9237
#
#   Best Val Acc: 0.9248 — saved to /kaggle/working/paper_outputs/checkpoints/efficientnet_best.pth

# %%
# ── Cell 12 — Train DL Baseline: ResNet18 ────────────────────
model_resnet = models.resnet18(weights=ResNet18_Weights.DEFAULT)
model_resnet.fc = nn.Linear(
    model_resnet.fc.in_features, num_classes
)
model_resnet, resnet_train_losses, resnet_val_losses = train_model(
    model_resnet, train_loader, val_loader,
    class_weights_tensor, device,
    epochs=DL_EPOCHS,
    lr=3e-4,
    weight_decay=0.01,
    optimizer_type="adamw",
    scheduler_type="cosine",
    checkpoint_path=os.path.join(OUT_DIR, "checkpoints", "resnet18_best.pth"),
    model_name="ResNet18"
)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 129MB/s]
# =======================================================
#   Training: ResNet18
# =======================================================
#   Epoch 01/20 | Train Loss: 0.8445 | Train Acc: 0.5846 | Val Loss: 1.0349 | Val Acc: 0.5604 ✅
#   Epoch 02/20 | Train Loss: 0.7192 | Train Acc: 0.6616 | Val Loss: 0.9595 | Val Acc: 0.6377 ✅
#   Epoch 03/20 | Train Loss: 0.6731 | Train Acc: 0.7146 | Val Loss: 0.9143 | Val Acc: 0.7013 ✅
#   Epoch 04/20 | Train Loss: 0.6342 | Train Acc: 0.7412 | Val Loss: 0.9327 | Val Acc: 0.6653
#   Epoch 05/20 | Train Loss: 0.6053 | Train Acc: 0.7774 | Val Loss: 0.8106 | Val Acc: 0.7564 ✅
#   Epoch 06/20 | Train Loss: 0.5758 | Train Acc: 0.7963 | Val Loss: 0.7985 | Val Acc: 0.7807 ✅
#   Epoch 07/20 | Train Loss: 0.5559 | Train Acc: 0.8242 | Val Loss: 0.7210 | Val Acc: 0.8347 ✅
#   Epoch 08/20 | Train Loss: 0.5431 | Train Acc: 0.8420 | Val Loss: 0.7361 | Val Acc: 0.8294
#   Epoch 09/20 | Train Loss: 0.5215 | Train Acc: 0.8612 | Val Loss: 0.7345 | Val Acc: 0.8199
#   Epoch 10/20 | Train Loss: 0.4919 | Train Acc: 0.8804 | Val Loss: 0.6796 | Val Acc: 0.8581 ✅
#   Epoch 11/20 | Train Loss: 0.4764 | Train Acc: 0.8991 | Val Loss: 0.6945 | Val Acc: 0.8676 ✅
#   Epoch 12/20 | Train Loss: 0.4656 | Train Acc: 0.9058 | Val Loss: 0.6983 | Val Acc: 0.8708 ✅
#   Epoch 13/20 | Train Loss: 0.4550 | Train Acc: 0.9136 | Val Loss: 0.6839 | Val Acc: 0.8792 ✅
#   Epoch 14/20 | Train Loss: 0.4381 | Train Acc: 0.9238 | Val Loss: 0.6507 | Val Acc: 0.9015 ✅
#   Epoch 15/20 | Train Loss: 0.4347 | Train Acc: 0.9248 | Val Loss: 0.6191 | Val Acc: 0.9163 ✅
#   Epoch 16/20 | Train Loss: 0.4255 | Train Acc: 0.9340 | Val Loss: 0.6268 | Val Acc: 0.9142
#   Epoch 17/20 | Train Loss: 0.4081 | Train Acc: 0.9448 | Val Loss: 0.6349 | Val Acc: 0.9078
#   Epoch 18/20 | Train Loss: 0.4149 | Train Acc: 0.9417 | Val Loss: 0.6149 | Val Acc: 0.9163
#   Epoch 19/20 | Train Loss: 0.4135 | Train Acc: 0.9395 | Val Loss: 0.6096 | Val Acc: 0.9184 ✅
#   Epoch 20/20 | Train Loss: 0.4089 | Train Acc: 0.9472 | Val Loss: 0.6159 | Val Acc: 0.9184
#
#   Best Val Acc: 0.9184 — saved to /kaggle/working/paper_outputs/checkpoints/resnet18_best.pth

# %%
# ── Cell 13 — Train DL Baseline: DenseNet121 ─────────────────
model_densenet = models.densenet121(weights=DenseNet121_Weights.DEFAULT)
model_densenet.classifier = nn.Linear(
    model_densenet.classifier.in_features, num_classes
)
model_densenet, densenet_train_losses, densenet_val_losses = train_model(
    model_densenet, train_loader, val_loader,
    class_weights_tensor, device,
    epochs=DL_EPOCHS,
    lr=3e-4,
    weight_decay=0.01,
    optimizer_type="adamw",
    scheduler_type="cosine",
    checkpoint_path=os.path.join(OUT_DIR, "checkpoints", "densenet121_best.pth"),
    model_name="DenseNet121"
)
# Out:
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/hub/checkpoints/densenet121-a639ec97.pth
# 100%|██████████| 30.8M/30.8M [00:00<00:00, 173MB/s]
# =======================================================
#   Training: DenseNet121
# =======================================================
#   Epoch 01/20 | Train Loss: 0.7978 | Train Acc: 0.6128 | Val Loss: 0.9754 | Val Acc: 0.6271 ✅
#   Epoch 02/20 | Train Loss: 0.6740 | Train Acc: 0.7147 | Val Loss: 0.8554 | Val Acc: 0.7352 ✅
#   Epoch 03/20 | Train Loss: 0.6227 | Train Acc: 0.7642 | Val Loss: 0.9043 | Val Acc: 0.6451
#   Epoch 04/20 | Train Loss: 0.5863 | Train Acc: 0.8008 | Val Loss: 0.7907 | Val Acc: 0.7341
#   Epoch 05/20 | Train Loss: 0.5414 | Train Acc: 0.8374 | Val Loss: 0.8013 | Val Acc: 0.7712 ✅
#   Epoch 06/20 | Train Loss: 0.5244 | Train Acc: 0.8630 | Val Loss: 0.6877 | Val Acc: 0.8867 ✅
#   Epoch 07/20 | Train Loss: 0.5027 | Train Acc: 0.8746 | Val Loss: 0.6655 | Val Acc: 0.8782
#   Epoch 08/20 | Train Loss: 0.4901 | Train Acc: 0.8882 | Val Loss: 0.6721 | Val Acc: 0.8941 ✅
#   Epoch 09/20 | Train Loss: 0.4690 | Train Acc: 0.9023 | Val Loss: 0.6872 | Val Acc: 0.8739
#   Epoch 10/20 | Train Loss: 0.4529 | Train Acc: 0.9101 | Val Loss: 0.6347 | Val Acc: 0.9142 ✅
#   Epoch 11/20 | Train Loss: 0.4513 | Train Acc: 0.9215 | Val Loss: 0.6441 | Val Acc: 0.9015
#   Epoch 12/20 | Train Loss: 0.4330 | Train Acc: 0.9303 | Val Loss: 0.6423 | Val Acc: 0.9068
#   Epoch 13/20 | Train Loss: 0.4311 | Train Acc: 0.9344 | Val Loss: 0.6199 | Val Acc: 0.9206 ✅
#   Epoch 14/20 | Train Loss: 0.4167 | Train Acc: 0.9426 | Val Loss: 0.6084 | Val Acc: 0.9227 ✅
#   Epoch 15/20 | Train Loss: 0.4130 | Train Acc: 0.9478 | Val Loss: 0.6008 | Val Acc: 0.9248 ✅
#   Epoch 16/20 | Train Loss: 0.4077 | Train Acc: 0.9490 | Val Loss: 0.5992 | Val Acc: 0.9280 ✅
#   Epoch 17/20 | Train Loss: 0.4011 | Train Acc: 0.9519 | Val Loss: 0.6080 | Val Acc: 0.9258
#   Epoch 18/20 | Train Loss: 0.3939 | Train Acc: 0.9552 | Val Loss: 0.5962 | Val Acc: 0.9269
#   Epoch 19/20 | Train Loss: 0.3877 | Train Acc: 0.9575 | Val Loss: 0.5984 | Val Acc: 0.9280
#   Epoch 20/20 | Train Loss: 0.3989 | Train Acc: 0.9540 | Val Loss: 0.5976 | Val Acc: 0.9269
#
#   Best Val Acc: 0.9280 — saved to /kaggle/working/paper_outputs/checkpoints/densenet121_best.pth

# %%
# ── Cell 14 — Train Transformer: ViT-Tiny ────────────────────
model_vit = timm.create_model(
    "vit_tiny_patch16_224", pretrained=True, num_classes=num_classes
)
model_vit, vit_train_losses, vit_val_losses = train_model(
    model_vit, train_loader, val_loader,
    class_weights_tensor, device,
    epochs=TRANSFORMER_EPOCHS,
    lr=1e-4,
    weight_decay=0.01,
    optimizer_type="adamw",
    scheduler_type="cosine",
    checkpoint_path=os.path.join(OUT_DIR, "checkpoints", "vit_best.pth"),
    model_name="ViT-Tiny"
)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/22.9M [00:00<?, ?B/s]
# =======================================================
#   Training: ViT-Tiny
# =======================================================
#   Epoch 01/25 | Train Loss: 0.7871 | Train Acc: 0.6207 | Val Loss: 0.9222 | Val Acc: 0.5964 ✅
#   Epoch 02/25 | Train Loss: 0.6269 | Train Acc: 0.7465 | Val Loss: 0.8506 | Val Acc: 0.7415 ✅
#   Epoch 03/25 | Train Loss: 0.5969 | Train Acc: 0.7842 | Val Loss: 0.8427 | Val Acc: 0.7786 ✅
#   Epoch 04/25 | Train Loss: 0.5530 | Train Acc: 0.8212 | Val Loss: 0.9079 | Val Acc: 0.6854
#   Epoch 05/25 | Train Loss: 0.5281 | Train Acc: 0.8491 | Val Loss: 0.7085 | Val Acc: 0.8422 ✅
#   Epoch 06/25 | Train Loss: 0.4970 | Train Acc: 0.8699 | Val Loss: 0.7198 | Val Acc: 0.8517 ✅
#   Epoch 07/25 | Train Loss: 0.4823 | Train Acc: 0.8873 | Val Loss: 0.8227 | Val Acc: 0.7574
#   Epoch 08/25 | Train Loss: 0.4703 | Train Acc: 0.9004 | Val Loss: 0.6976 | Val Acc: 0.8665 ✅
#   Epoch 09/25 | Train Loss: 0.4632 | Train Acc: 0.9075 | Val Loss: 0.6933 | Val Acc: 0.8771 ✅
#   Epoch 10/25 | Train Loss: 0.4498 | Train Acc: 0.9164 | Val Loss: 0.6676 | Val Acc: 0.8814 ✅
#   Epoch 11/25 | Train Loss: 0.4432 | Train Acc: 0.9250 | Val Loss: 0.6830 | Val Acc: 0.8761
#   Epoch 12/25 | Train Loss: 0.4317 | Train Acc: 0.9334 | Val Loss: 0.6596 | Val Acc: 0.8941 ✅
#   Epoch 13/25 | Train Loss: 0.4251 | Train Acc: 0.9322 | Val Loss: 0.6424 | Val Acc: 0.9068 ✅
#   Epoch 14/25 | Train Loss: 0.4113 | Train Acc: 0.9411 | Val Loss: 0.6296 | Val Acc: 0.9110 ✅
#   Epoch 15/25 | Train Loss: 0.4070 | Train Acc: 0.9473 | Val Loss: 0.6493 | Val Acc: 0.9078
#   Epoch 16/25 | Train Loss: 0.4139 | Train Acc: 0.9445 | Val Loss: 0.6948 | Val Acc: 0.8951
#   Epoch 17/25 | Train Loss: 0.4009 | Train Acc: 0.9509 | Val Loss: 0.6568 | Val Acc: 0.9089
#   Epoch 18/25 | Train Loss: 0.3940 | Train Acc: 0.9570 | Val Loss: 0.6456 | Val Acc: 0.9121 ✅
#   Epoch 19/25 | Train Loss: 0.3973 | Train Acc: 0.9560 | Val Loss: 0.6490 | Val Acc: 0.9142 ✅
#   Epoch 20/25 | Train Loss: 0.3903 | Train Acc: 0.9604 | Val Loss: 0.6489 | Val Acc: 0.9174 ✅
#   Epoch 21/25 | Train Loss: 0.3779 | Train Acc: 0.9612 | Val Loss: 0.6511 | Val Acc: 0.9131
#   Epoch 22/25 | Train Loss: 0.3844 | Train Acc: 0.9613 | Val Loss: 0.6607 | Val Acc: 0.9121
#   Epoch 23/25 | Train Loss: 0.3787 | Train Acc: 0.9649 | Val Loss: 0.6703 | Val Acc: 0.9078
#   Epoch 24/25 | Train Loss: 0.3948 | Train Acc: 0.9575 | Val Loss: 0.6662 | Val Acc: 0.9100
#   Epoch 25/25 | Train Loss: 0.3867 | Train Acc: 0.9617 | Val Loss: 0.6668 | Val Acc: 0.9110
#
#   Best Val Acc: 0.9174 — saved to /kaggle/working/paper_outputs/checkpoints/vit_best.pth

# %%
# ── Cell 15 — Train Transformer: Swin-Tiny ───────────────────
class_weights_tensor = torch.tensor(
    compute_class_weight(
        class_weight="balanced",
        classes=np.arange(num_classes),
        y=np.array([train_dataset.targets[i] for i in train_idx])
    ),
    dtype=torch.float
).to(device)

model_swin = timm.create_model(
    "swin_tiny_patch4_window7_224", pretrained=True, num_classes=0
)
in_features = model_swin.num_features

class SwinClassifier(nn.Module):
    def __init__(self, backbone, in_features, num_classes):
        super().__init__()
        self.backbone = backbone
        self.dropout  = nn.Dropout(0.3)
        self.fc       = nn.Linear(in_features, num_classes)

    def forward(self, x):
        x = self.backbone(x)
        if x.dim() == 4:
            x = x.mean(dim=[2, 3])
        elif x.dim() == 3:
            x = x.mean(dim=1)
        x = self.dropout(x)
        return self.fc(x)

model_swin = SwinClassifier(model_swin, in_features, num_classes)
model_swin.to(device)

with torch.no_grad():
    dummy = torch.randn(2, 3, 224, 224).to(device)
    out   = model_swin(dummy)
    print(f"Swin output shape: {out.shape}")

model_swin, swin_train_losses, swin_val_losses = train_model(
    model_swin, train_loader, val_loader,
    class_weights_tensor, device,
    epochs=TRANSFORMER_EPOCHS,
    lr=1e-4,
    weight_decay=0.05,
    optimizer_type="adamw",
    scheduler_type="cosine",
    checkpoint_path=os.path.join(OUT_DIR, "checkpoints", "swin_best.pth"),
    model_name="Swin-Tiny"
)
# Out:
# model.safetensors:   0%|          | 0.00/114M [00:00<?, ?B/s]
# Swin output shape: torch.Size([2, 4])
#
# =======================================================
#   Training: Swin-Tiny
# =======================================================
#   Epoch 01/25 | Train Loss: 0.7539 | Train Acc: 0.6363 | Val Loss: 0.8852 | Val Acc: 0.6748 ✅
#   Epoch 02/25 | Train Loss: 0.6028 | Train Acc: 0.7725 | Val Loss: 0.7823 | Val Acc: 0.7638 ✅
#   Epoch 03/25 | Train Loss: 0.5504 | Train Acc: 0.8281 | Val Loss: 0.8108 | Val Acc: 0.7807 ✅
#   Epoch 04/25 | Train Loss: 0.5287 | Train Acc: 0.8543 | Val Loss: 0.7078 | Val Acc: 0.8538 ✅
#   Epoch 05/25 | Train Loss: 0.4926 | Train Acc: 0.8860 | Val Loss: 0.6737 | Val Acc: 0.8771 ✅
#   Epoch 06/25 | Train Loss: 0.4857 | Train Acc: 0.8959 | Val Loss: 0.7811 | Val Acc: 0.8337
#   Epoch 07/25 | Train Loss: 0.4664 | Train Acc: 0.9079 | Val Loss: 0.6347 | Val Acc: 0.8983 ✅
#   Epoch 08/25 | Train Loss: 0.4571 | Train Acc: 0.9135 | Val Loss: 0.6586 | Val Acc: 0.8962
#   Epoch 09/25 | Train Loss: 0.4462 | Train Acc: 0.9232 | Val Loss: 0.6480 | Val Acc: 0.9015 ✅
#   Epoch 10/25 | Train Loss: 0.4371 | Train Acc: 0.9264 | Val Loss: 0.6928 | Val Acc: 0.8771
#   Epoch 11/25 | Train Loss: 0.4205 | Train Acc: 0.9350 | Val Loss: 0.6314 | Val Acc: 0.9184 ✅
#   Epoch 12/25 | Train Loss: 0.4296 | Train Acc: 0.9359 | Val Loss: 0.6314 | Val Acc: 0.9163
#   Epoch 13/25 | Train Loss: 0.4184 | Train Acc: 0.9444 | Val Loss: 0.6404 | Val Acc: 0.9121
#   Epoch 14/25 | Train Loss: 0.4099 | Train Acc: 0.9468 | Val Loss: 0.6302 | Val Acc: 0.9163
#   Epoch 15/25 | Train Loss: 0.4070 | Train Acc: 0.9486 | Val Loss: 0.6253 | Val Acc: 0.9153
#   Epoch 17/25 | Train Loss: 0.4062 | Train Acc: 0.9543 | Val Loss: 0.6239 | Val Acc: 0.9206
#   Epoch 18/25 | Train Loss: 0.3989 | Train Acc: 0.9522 | Val Loss: 0.6165 | Val Acc: 0.9248 ✅
#   Epoch 19/25 | Train Loss: 0.3990 | Train Acc: 0.9562 | Val Loss: 0.6357 | Val Acc: 0.9184
#   Epoch 20/25 | Train Loss: 0.3932 | Train Acc: 0.9566 | Val Loss: 0.6247 | Val Acc: 0.9248
#   Epoch 21/25 | Train Loss: 0.3912 | Train Acc: 0.9603 | Val Loss: 0.6182 | Val Acc: 0.9248
#   Epoch 22/25 | Train Loss: 0.3777 | Train Acc: 0.9644 | Val Loss: 0.6288 | Val Acc: 0.9248
#   Epoch 23/25 | Train Loss: 0.3840 | Train Acc: 0.9640 | Val Loss: 0.6264 | Val Acc: 0.9301 ✅
#   Epoch 24/25 | Train Loss: 0.3808 | Train Acc: 0.9649 | Val Loss: 0.6259 | Val Acc: 0.9301
#   Epoch 25/25 | Train Loss: 0.3874 | Train Acc: 0.9620 | Val Loss: 0.6261 | Val Acc: 0.9301
#
#   Best Val Acc: 0.9301 — saved to /kaggle/working/paper_outputs/checkpoints/swin_best.pth

# %%
# ── Cell 16 — Evaluate All 6 Models ──────────────────────────
all_models = {
    "MobileNetV3-Small": model_mobilenet,
    "EfficientNetB0":    model_eff,
    "ResNet18":          model_resnet,
    "DenseNet121":       model_densenet,
    "ViT-Tiny":          model_vit,
    "Swin-Tiny":         model_swin
}

all_reports       = {}
all_model_metrics = {}

for name, model in all_models.items():
    print(f"\nEvaluating {name}...")
    labels, preds, report, cm     = evaluate(model, test_loader, class_names, device)
    params, size_mb, latency, fps = model_info(model, device)

    all_reports[name]       = report
    all_model_metrics[name] = {
        "accuracy":           report["accuracy"],
        "precision_weighted": report["weighted avg"]["precision"],
        "recall_weighted":    report["weighted avg"]["recall"],
        "weighted_f1":        report["weighted avg"]["f1-score"],
        "macro_f1":           report["macro avg"]["f1-score"],
        "params_M":           round(params / 1e6, 2),
        "size_mb":            size_mb,
        "latency_ms":         latency * 1000,
        "fps":                fps,
        "cm":                 cm
    }
    print(f"  Acc: {report['accuracy']:.4f} | W-F1: {report['weighted avg']['f1-score']:.4f} | "
          f"Params: {round(params/1e6, 2)}M | Size: {size_mb:.2f}MB | "
          f"Latency: {latency*1000:.2f}ms | FPS: {fps:.2f}")

plot_models = ["MobileNetV3-Small", "EfficientNetB0", "ResNet18",
               "DenseNet121", "ViT-Tiny", "Swin-Tiny"]

summary_df = pd.DataFrame(all_model_metrics).T[[
    "accuracy", "precision_weighted", "recall_weighted",
    "weighted_f1", "macro_f1", "params_M", "size_mb", "latency_ms", "fps"
]].loc[plot_models]

print("\n=== Summary Table ===")
display(summary_df)
summary_df.to_csv(os.path.join(OUT_DIR, "model_summary_results.csv"))
# Out:
# Evaluating MobileNetV3-Small...
#   Acc: 0.9333 | W-F1: 0.9348 | Params: 1.52M | Size: 5.81MB | Latency: 5.11ms | FPS: 195.78
#
# Evaluating EfficientNetB0...
#   Acc: 0.9322 | W-F1: 0.9335 | Params: 4.01M | Size: 15.31MB | Latency: 8.49ms | FPS: 117.76
#
# Evaluating ResNet18...
#   Acc: 0.9301 | W-F1: 0.9321 | Params: 11.18M | Size: 42.64MB | Latency: 3.09ms | FPS: 323.68
#
# Evaluating DenseNet121...
#   Acc: 0.9280 | W-F1: 0.9295 | Params: 6.96M | Size: 26.54MB | Latency: 14.93ms | FPS: 66.99
#
# Evaluating ViT-Tiny...
#   Acc: 0.9269 | W-F1: 0.9284 | Params: 5.53M | Size: 21.08MB | Latency: 4.67ms | FPS: 214.04
#
# Evaluating Swin-Tiny...
#   Acc: 0.9311 | W-F1: 0.9323 | Params: 27.52M | Size: 104.99MB | Latency: 9.98ms | FPS: 100.24
#
# === Summary Table ===
#                    accuracy precision_weighted recall_weighted weighted_f1  \
# MobileNetV3-Small  0.933263           0.942784        0.933263    0.934839
# EfficientNetB0     0.932203            0.94013        0.932203    0.933481
# ResNet18           0.930085           0.943313        0.930085    0.932142
# DenseNet121        0.927966           0.939674        0.927966    0.929502
# ViT-Tiny           0.926907           0.935407        0.926907    0.928365
# Swin-Tiny          0.931144           0.938147        0.931144     0.93231
#
#                    macro_f1 params_M     size_mb latency_ms         fps
# MobileNetV3-Small  0.916588     1.52    5.805801   5.107855  195.776913
# EfficientNetB0     0.915019     4.01   15.307129   8.492095  117.756574
# ResNet18           0.913919    11.18   42.642838   3.089516  323.675337
# DenseNet121        0.911457     6.96   26.542496  14.928012   66.988156
# ViT-Tiny           0.909733     5.53    21.07692   4.672052  214.038702
# Swin-Tiny          0.914544    27.52  104.989738   9.976063  100.239946

# %%
# ══════════════════════════════════════════════════════════════════════════════
# Cell 17 — All Evaluation Plots  (Loss · CM · F1 · Size · Latency)
# ══════════════════════════════════════════════════════════════════════════════

os.makedirs(os.path.join(OUT_DIR, "plots"),  exist_ok=True)
os.makedirs(os.path.join(OUT_DIR, "gradcam"), exist_ok=True)

plot_models = [
    "MobileNetV3-Small", "EfficientNetB0", "ResNet18",
    "DenseNet121",       "ViT-Tiny",       "Swin-Tiny"
]

short_labels = ["BLB", "HL", "RB", "TU"]

# ── helper: save both PNG + PDF ───────────────────────────────────────────────
def save_fig(fig, subfolder, filename):
    base = os.path.join(OUT_DIR, subfolder, filename)
    fig.savefig(base + ".png", dpi=300, bbox_inches="tight")
    fig.savefig(base + ".pdf",            bbox_inches="tight")
    print(f"  saved → {base}.png / .pdf")

# ── 1) Loss Curves ────────────────────────────────────────────────────────────
all_train_losses = {
    "MobileNetV3-Small": mobilenet_train_losses,
    "EfficientNetB0":    eff_train_losses,
    "ResNet18":          resnet_train_losses,
    "DenseNet121":       densenet_train_losses,
    "ViT-Tiny":          vit_train_losses,
    "Swin-Tiny":         swin_train_losses,
}
all_val_losses = {
    "MobileNetV3-Small": mobilenet_val_losses,
    "EfficientNetB0":    eff_val_losses,
    "ResNet18":          resnet_val_losses,
    "DenseNet121":       densenet_val_losses,
    "ViT-Tiny":          vit_val_losses,
    "Swin-Tiny":         swin_val_losses,
}

fig, axes = plt.subplots(2, 3, figsize=(13, 8))
axes = axes.flatten()
for i, name in enumerate(plot_models):
    axes[i].plot(all_train_losses[name], label="Train", marker='o', markersize=3)
    axes[i].plot(all_val_losses[name],   label="Val",   marker='s', markersize=3)
    axes[i].set_title(name, fontsize=10, fontweight='bold')
    axes[i].set_xlabel("Epoch", fontsize=8)
    axes[i].set_ylabel("Loss",  fontsize=8)
    axes[i].legend(fontsize=7)
    axes[i].grid(True, alpha=0.4)
    axes[i].tick_params(labelsize=7)
plt.suptitle("Training vs Validation Loss — All Models",
             fontsize=13, fontweight='bold')
plt.tight_layout()
save_fig(fig, "plots", "loss_curves")
plt.show()

# ── 2) Confusion Matrices ─────────────────────────────────────────────────────
fig, axes = plt.subplots(2, 3, figsize=(13, 8))
axes = axes.flatten()
for i, name in enumerate(plot_models):
    cm = all_model_metrics[name]["cm"]
    sns.heatmap(
        cm, annot=True, fmt='d', cmap='Blues',
        xticklabels=short_labels, yticklabels=short_labels,
        ax=axes[i], annot_kws={"size": 9}, linewidths=0.5
    )
    axes[i].set_title(name, fontsize=10, fontweight='bold', pad=6)
    axes[i].set_xlabel("Predicted", fontsize=8)
    axes[i].set_ylabel("Actual",    fontsize=8)
    axes[i].tick_params(axis='x', labelsize=8)
    axes[i].tick_params(axis='y', labelsize=8, rotation=0)

legend_text = "BLB=Bacterial Leaf Blight  |  HL=Healthy Leaf  |  RB=Rice Blast  |  TU=Tungro"
plt.figtext(0.5, 0.01, legend_text, ha='center', fontsize=8, style='italic')
plt.suptitle("Confusion Matrices — All Models", fontsize=13, fontweight='bold')
plt.tight_layout(rect=[0, 0.03, 1, 1])
save_fig(fig, "plots", "confusion_matrix_all")
plt.show()

# ── 3) Per-class F1 ───────────────────────────────────────────────────────────
x     = np.arange(len(class_names))
width = 0.13

fig, ax = plt.subplots(figsize=(13, 5))
for i, name in enumerate(plot_models):
    f1_scores = [all_reports[name][cls]["f1-score"] for cls in class_names]
    offset    = (i - 2.5) * width
    ax.bar(x + offset, f1_scores, width=width, label=name)

ax.set_xticks(x)
ax.set_xticklabels(class_names, rotation=15, fontsize=9)
ax.set_ylabel("F1-score")
ax.set_title("Per-class F1-score Comparison — All Models",
             fontsize=12, fontweight='bold')
ax.set_ylim(0, 1.05)
ax.legend(fontsize=8)
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
save_fig(fig, "plots", "per_class_f1_comparison")
plt.show()

# ── 4) Accuracy vs Model Size ─────────────────────────────────────────────────
acc  = [all_model_metrics[m]["accuracy"]  for m in plot_models]
size = [all_model_metrics[m]["size_mb"]   for m in plot_models]

fig, ax = plt.subplots(figsize=(7, 5))
ax.scatter(size, acc, s=120, zorder=5)
for i, m in enumerate(plot_models):
    ax.annotate(m, (size[i], acc[i]),
                xytext=(6, 0), textcoords='offset points',
                fontsize=7, va='center')
ax.set_xlabel("Model Size (MB)")
ax.set_ylabel("Accuracy")
ax.set_title("Accuracy vs Model Size Trade-off",
             fontsize=12, fontweight='bold')
ax.grid(True, alpha=0.3)
plt.tight_layout()
save_fig(fig, "plots", "accuracy_vs_model_size")
plt.show()

# ── 5) Latency Comparison ─────────────────────────────────────────────────────
latencies = [all_model_metrics[m]["latency_ms"] for m in plot_models]

fig, ax = plt.subplots(figsize=(9, 5))
bars = ax.bar(plot_models, latencies, color='steelblue', width=0.55)
ax.bar_label(bars, fmt='%.1f ms', fontsize=8, padding=3)
ax.set_ylabel("Latency (ms / image)")
ax.set_title("Inference Latency Comparison",
             fontsize=12, fontweight='bold')
ax.set_ylim(0, max(latencies) * 1.2)
ax.tick_params(axis='x', rotation=15, labelsize=8)
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
save_fig(fig, "plots", "latency_comparison")
plt.show()

print("\n✅ Cell 17 complete — all plots saved (PNG + PDF)")
print(f"   → {os.path.join(OUT_DIR, 'plots')}/")
# Out:
#   saved → /kaggle/working/paper_outputs/plots/loss_curves.png / .pdf
#   saved → /kaggle/working/paper_outputs/plots/confusion_matrix_all.png / .pdf
#   saved → /kaggle/working/paper_outputs/plots/per_class_f1_comparison.png / .pdf
#   saved → /kaggle/working/paper_outputs/plots/accuracy_vs_model_size.png / .pdf
#   saved → /kaggle/working/paper_outputs/plots/latency_comparison.png / .pdf
# ✅ Cell 17 complete — all plots saved (PNG + PDF)
#    → /kaggle/working/paper_outputs/plots/

# %%
# ══════════════════════════════════════════════════════════════════════════════
# Cell 18 — Grad-CAM Visualization  (FIXED)
#            Layout : 7 rows × 5 cols
#            Row 0  : Original images (one per class)
#            Row 1–6: One model per row → Grad-CAM heatmap per class
#            Col 0  : Model name label  |  Col 1–4: BLB / HL / RB / TU
#
# FIXES APPLIED:
#   FIX 1 — Tungro column blank:
#            enumerate(sample_indices, start=0) + continue was consuming the
#            first sample index for the label column, shifting all heatmap
#            columns left by one and leaving Tungro with nothing to render.
#            Fixed by handling col 0 OUTSIDE the loop and using start=1.
#
#   FIX 2 — Rogue colorbar axes:
#            GradCAM internals can inject extra axes into the figure.
#            Fixed by removing any axes not in the expected grid after the loop.
#
#   FIX 3 — tight_layout UserWarning:
#            plt.tight_layout() conflicts with suptitle(y=1.005) + figtext.
#            Fixed by replacing it with explicit fig.subplots_adjust().
# ══════════════════════════════════════════════════════════════════════════════
import math
from pytorch_grad_cam import GradCAM
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget
from pytorch_grad_cam.utils.image import show_cam_on_image

inv_mean = np.array([0.485, 0.456, 0.406])
inv_std  = np.array([0.229, 0.224, 0.225])

def denormalize_image(img_tensor):
    img = img_tensor.permute(1, 2, 0).cpu().numpy()
    return np.clip((img * inv_std) + inv_mean, 0, 1)

# ── reshape transforms ────────────────────────────────────────────────────────
def reshape_transform_vit(tensor, height=14, width=14):
    tensor = tensor[:, 1:, :]          # remove CLS token
    result = tensor.reshape(tensor.size(0), height, width, tensor.size(2))
    return result.permute(0, 3, 1, 2)

def reshape_transform_swin(tensor):
    """
    timm newer  → (B, H, W, C) — already spatial
    timm older  → (B, L, C)    — needs reshape
    """
    if tensor.dim() == 4:
        return tensor.permute(0, 3, 1, 2)          # (B,H,W,C)→(B,C,H,W)
    B, L, C = tensor.shape
    H = W = int(math.sqrt(L))
    if H * W != L:
        return tensor.permute(0, 2, 1).unsqueeze(2) # fallback
    return tensor.reshape(B, H, W, C).permute(0, 3, 1, 2)

def get_pred(model, img_tensor):
    model.eval()
    with torch.no_grad():
        out = model(img_tensor.unsqueeze(0).to(device))
        return out.argmax(dim=1).item()

# ── model registry ────────────────────────────────────────────────────────────
gradcam_models = {
    "MobileNetV3": model_mobilenet,
    "EffNetB0":    model_eff,
    "ResNet18":    model_resnet,
    "DenseNet121": model_densenet,
    "ViT-Tiny":    model_vit,
    "Swin-Tiny":   model_swin,
}
target_layers_map = {
    "MobileNetV3": [model_mobilenet.features[-1]],
    "EffNetB0":    [model_eff.features[-1]],
    "ResNet18":    [model_resnet.layer4[-1]],
    "DenseNet121": [model_densenet.features[-1]],
    "ViT-Tiny":    [model_vit.blocks[-1].norm1],
    "Swin-Tiny":   [model_swin.backbone.norm],
}
reshape_map = {
    "ViT-Tiny":  reshape_transform_vit,
    "Swin-Tiny": reshape_transform_swin,
}

model_names = list(gradcam_models.keys())   # 6

# ── Find 1 correctly predicted sample per class (all 6 models agree) ─────────
print("Finding representative samples …")
seen_classes = {}
for idx in tqdm(range(len(test_ds)), ncols=70):
    img, label = test_ds[idx]
    if label in seen_classes:
        continue
    if all(get_pred(m, img) == label for m in gradcam_models.values()):
        seen_classes[label] = idx
    if len(seen_classes) == num_classes:
        break

sample_indices = [seen_classes[c] for c in sorted(seen_classes.keys())]
print("Classes found:", [class_names[test_ds[i][1]] for i in sample_indices])

# ── Grid setup: 7 rows × 5 cols ──────────────────────────────────────────────
#   row 0      → Original images header row
#   row 1..6   → Grad-CAM per model
#   col 0      → Model name label (text only, no image)
#   col 1..4   → Disease classes (BLB / HL / RB / TU)

n_rows  = len(model_names) + 1        # 7
n_cols  = len(sample_indices) + 1     # 5
cell_in = 2.8                         # inch per cell

fig, axes = plt.subplots(
    n_rows, n_cols,
    figsize=(n_cols * cell_in, n_rows * cell_in),
    gridspec_kw={'wspace': 0.03, 'hspace': 0.10}
)

# ── Row 0: Header row — Original images ──────────────────────────────────────
axes[0, 0].axis('off')
axes[0, 0].text(0.5, 0.5, "Original",
                ha='center', va='center',
                fontsize=9, fontweight='bold',
                transform=axes[0, 0].transAxes)

for col_idx, idx in enumerate(sample_indices, start=1):
    img, label = test_ds[idx]
    axes[0, col_idx].imshow(denormalize_image(img))
    axes[0, col_idx].set_xticks([])
    axes[0, col_idx].set_yticks([])
    axes[0, col_idx].set_title(class_names[label],
                                fontsize=10, fontweight='bold', pad=5)

# ── Rows 1–6: Grad-CAM per model ─────────────────────────────────────────────
# FIX 1: Col 0 is handled OUTSIDE the sample loop.
#         Heatmap loop uses start=1 so all 4 class columns are filled.
for row_idx, name in enumerate(model_names, start=1):
    model = gradcam_models[name]
    model.eval()

    # ── Col 0: model name as centred rotated text — no image ──────────────
    axes[row_idx, 0].axis('off')
    axes[row_idx, 0].text(0.5, 0.5, name,
                           ha='center', va='center',
                           fontsize=10, fontweight='bold',
                           rotation=90,
                           transform=axes[row_idx, 0].transAxes)

    # ── Col 1–4: Grad-CAM heatmap for EVERY class (start=1 fixes Tungro) ──
    for col_idx, idx in enumerate(sample_indices, start=1):
        img, label   = test_ds[idx]
        rgb_img      = denormalize_image(img)
        input_tensor = img.unsqueeze(0).to(device)

        pred    = get_pred(model, img)
        reshape = reshape_map.get(name, None)

        cam = GradCAM(
            model=model,
            target_layers=target_layers_map[name],
            reshape_transform=reshape
        )
        grayscale = cam(
            input_tensor=input_tensor,
            targets=[ClassifierOutputTarget(pred)]
        )[0]
        cam_img = show_cam_on_image(rgb_img, grayscale, use_rgb=True)

        axes[row_idx, col_idx].imshow(cam_img)
        axes[row_idx, col_idx].set_xticks([])
        axes[row_idx, col_idx].set_yticks([])

        # prediction label (green = correct, red = wrong)
        color = 'lime' if pred == label else 'red'
        axes[row_idx, col_idx].set_xlabel(
            f"↑ {class_names[pred]}",
            fontsize=9.5, color=color, labelpad=2
        )

# FIX 2: Remove any rogue colorbar/extra axes added by GradCAM internals
expected_axes = set(axes.flatten())
for ax in fig.axes[:]:          # iterate a shallow copy so removal is safe
    if ax not in expected_axes:
        ax.remove()

# ── Title + legend ────────────────────────────────────────────────────────────
plt.suptitle(
    "Grad-CAM Visualization  —  Rows: Models  |  Columns: Disease Classes",
    fontsize=12, fontweight='bold', y=1.005
)
legend_text = (
    "BLB = Bacterial Leaf Blight  |  HL = Healthy Leaf  "
    "|  RB = Rice Blast  |  TU = Tungro\n"
    "xlabel color:  green = correct prediction,  red = misclassified"
)
plt.figtext(0.5, -0.015, legend_text, ha='center', fontsize=8, style='italic')

# FIX 3: Replace plt.tight_layout() with subplots_adjust — no more UserWarning
fig.subplots_adjust(top=0.97, bottom=0.04, left=0.06, right=0.99,
                    wspace=0.03, hspace=0.10)

# ── Save PNG + PDF ────────────────────────────────────────────────────────────
save_fig(fig, "gradcam", "gradcam_7x5_grid")   # reuses save_fig() from Cell 17
plt.show()

# ── Final summary ─────────────────────────────────────────────────────────────
print("\n" + "="*55)
print("  All outputs saved →", OUT_DIR)
print("="*55)
for f in [
    "plots/loss_curves",
    "plots/confusion_matrix_all",
    "plots/per_class_f1_comparison",
    "plots/accuracy_vs_model_size",
    "plots/latency_comparison",
    "gradcam/gradcam_7x5_grid",
]:
    print(f"  {f}.png  +  .pdf")
print("="*55)
print("\n✅ Cell 18 complete — Grad-CAM saved (PNG + PDF)")
# Out:
# Finding representative samples …
#   3%|█                               | 33/944 [00:00<00:19, 47.02it/s]
# Classes found: ['Bacterial Leaf Blight', 'Healthy _leaf', 'Rice Blast', 'Tungro']
#   saved → /kaggle/working/paper_outputs/gradcam/gradcam_7x5_grid.png / .pdf
# =======================================================
#   All outputs saved → /kaggle/working/paper_outputs
# =======================================================
#   plots/loss_curves.png  +  .pdf
#   plots/confusion_matrix_all.png  +  .pdf
#   plots/per_class_f1_comparison.png  +  .pdf
#   plots/accuracy_vs_model_size.png  +  .pdf
#   plots/latency_comparison.png  +  .pdf
#   gradcam/gradcam_7x5_grid.png  +  .pdf
# =======================================================
#
# ✅ Cell 18 complete — Grad-CAM saved (PNG + PDF)

# %%
img, label = test_ds[0]

print("SHAPE:", img.shape)
print("MIN:", img.min().item())
print("MAX:", img.max().item())
print("MEAN:", img.mean().item())
# Out:
# SHAPE: torch.Size([3, 224, 224])
# MIN: -1.4558606147766113
# MAX: 2.517995834350586
# MEAN: 1.4951387643814087
