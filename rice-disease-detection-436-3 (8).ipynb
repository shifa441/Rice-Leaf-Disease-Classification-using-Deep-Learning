# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150555.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_145527.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_144634.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_155701.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_154546.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_161614.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150917.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_152001.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_155923.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_152354.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_160709.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150912.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_161917.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_150427.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_160749.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_155003.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150737.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_152018.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150540.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_154145.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_160200.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_143323 - Copy.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_152745.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_151608.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_152732.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_155939.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_152033.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_143323.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_160215.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_161747.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_161236.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150537.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_160946.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_162404.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_161758.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_150058.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_145106.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_154257.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241031_161612.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_152405.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_152556.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_145329.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150732.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_154224.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_153905.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_153934.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_154316.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_161626.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_162342.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_160533.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_160917.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_160630.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_160430.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150444.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_153625.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_144021.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_151203.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150709.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_152632.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_160145.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_150651.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_152007.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_152713.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_152021.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_161011.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150459.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_150446.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_144121.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_154325.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150725.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_152010.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_152052.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150723.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_152107.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150545.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_154222.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_161104.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150527.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_160236.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_151655.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150728.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_160056.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_155854.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_151006.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_155443.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_145845.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_155619.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_160315.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_152343.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_160641.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_155907.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_162608.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150546.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150730.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_161909.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_155339.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_160011.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_145654.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_153453.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_154231.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150553.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_160041.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150900.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_161445.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_154214.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150549.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_151503.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_152018.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_161133.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_152625.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_160457.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_150722.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_161725.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150538.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_151958.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150718.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_161414.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_161843.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_162439.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_153818.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_145405.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_160025.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_144130.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_161221.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150712.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150525.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_152038.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_154126.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_161817.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_154229.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_144721.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_154225.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150714.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_153042.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_150111.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_162151.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150550.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_143547.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_152015.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_155600.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_160257.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150535.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_154813.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_162131.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_160326.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_162334.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150904.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_152012.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_154150.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150734.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150736.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_155305.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150717.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_151656.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150905.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150557.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_152034.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_152037.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150914.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241031_161648.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_153756.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_144857.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150902.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_154616.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_162626.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_143503.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_152904.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_143503 - Copy.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_154221.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_144032.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_162616.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_150857.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_150030.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_161259.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150733.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_161828.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150541.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_154220.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_152004.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_162142.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_160048.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_154628.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_162202.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150445.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_145241.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_160404.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_154228.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_153651.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_151524.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_161714.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150548.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_153445.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_152016.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_145943.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_152545.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_152025.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_154226.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_160545.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_155426.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_144239.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_151638.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150722.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_151016.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_150509.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_163309.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_154227.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_155505.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_155652.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_154420.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_155532.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150916.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_161937.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_162059.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_155256.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_145258.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_155028.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_144709.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_161040.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_152106.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_162350.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_153603.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_160610.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_152035.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_155637.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_151950.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_150844.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241031_161629.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_154745.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_154133.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_154127.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_162649.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_162000.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_162244.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150406.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_145710.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150534.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_162636.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_150933.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150724.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_161341.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_154557.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_153402.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_162219.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_161247.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_152039.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_145625.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150443.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150542.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_145229.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150500.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_160739.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_162233.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_153136.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_143947.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_150227.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_144251.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_161157.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_161112.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_151039.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_155323.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_144042.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_152718.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_161432.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150735.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_155126.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_144620.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_161505.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150715.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_145754.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_154223.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_160517.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_161212.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_154916.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_161053.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_163500.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_151859.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_154124.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_151030.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150530.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150556.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_150327_Bokeh.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_161332.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150408.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_155835.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_155406.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_154023.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_155203.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_162522.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_161457.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_155455.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_152024.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_160439.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_152029.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_160955.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_160727.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/20241114_150918.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241114_154936.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/orginal/IMG_20241031_165122.jpg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_825.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_6253.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_910.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_2794.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_6466.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_9619.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_808.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_1276.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_3569.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_8901.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_6794.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_7101.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_8505.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_4281.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_5590.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_8471.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_2998.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_4374.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_2652.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_4028.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_7363.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_4156.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_2944.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_8696.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_1823.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_469.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_7590.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_5258.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_9002.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_9020.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_5588.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_539.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_9760.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_3555.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_4588.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_4632.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_1877.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_308.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_1939.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_1964.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_1009.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_9809.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_1237.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_4268.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_1290.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_7069.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_5535.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_7120.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_4432.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_6941.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_599.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_4314.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_642.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_1108.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_620.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_4816.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_8016.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_1696.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_250.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_2847.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_2562.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_6367.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_7094.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_1596.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_9608.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_2659.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_546.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_5076.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_1379.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_1677.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_9617.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_5245.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_3472.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_6126.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_6647.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_5780.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_6512.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_7065.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_8968.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_459.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_7812.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_1707.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_3365.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_1176.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_7011.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_9912.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_6720.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_4175.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_8754.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_3605.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_9874.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_9699.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_4563.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_9873.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_8485.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_8496.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_6772.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_8529.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_2816.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_9500.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_1213.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_3658.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_4344.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_8536.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_2786.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_2785.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_7055.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_8488.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_5011.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_1847.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_6177.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_9742.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Tungro/augmented/Aug Tungro/aug_0_7468.jpeg
# ...
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_6798.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_9339.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_352.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_3129.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_5912.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_4007.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_542.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_7762.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_5450.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_5843.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_7056.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_9486.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_7880.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_8760.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_2555.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_2221.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_1608.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_5519.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_1426.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_222.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_7213.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_2426.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_389.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_963.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_4371.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_8128.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_9901.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_4264.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_6088.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_1547.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_4325.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_1553.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_6644.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_1172.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_7345.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_7826.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_4421.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_1583.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_779.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_7031.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_3405.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_7178.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_851.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_8296.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_6321.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_7996.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_7098.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_1949.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_1997.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_2610.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_7704.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_8165.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_1752.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_484.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_7549.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_2149.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_1039.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_1522.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_2315.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_2147.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_3585.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_7092.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_7232.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_5173.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_2058.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_2692.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_2131.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_7750.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_5415.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_8146.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_1740.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_4610.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_5460.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_3634.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_5260.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_7099.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_415.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_3362.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_3507.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_5434.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_2615.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_4169.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_6407.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_9508.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_9330.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_5024.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_3798.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_3420.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_608.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_9123.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_7302.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_3715.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_2910.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_6831.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_8195.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_2950.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_4993.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_9531.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_3350.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_7650.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_7135.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_6428.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_6116.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_3568.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_7210.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_7279.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_4606.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_9325.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_1401.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_694.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_9773.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_1506.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_428.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_4903.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_5250.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_9732.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_5633.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_4144.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_7440.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_4929.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_6010.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_7348.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_9678.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_6495.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_2267.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_9360.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_2319.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_6210.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_6763.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_1574.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_7528.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_9404.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_2725.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_9810.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_780.jpeg
# /kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset/Rice/augmented/Aug Rice/aug_0_8212.jpeg

# %%
# !pip install -q grad-cam timm tqdm
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 58.1 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for grad-cam (pyproject.toml) ... done

# %%
import os, time, random, shutil, math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

import torch
import torch.nn as nn
import torch.optim as optim
import timm
from tqdm import tqdm

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils.class_weight import compute_class_weight

from torchvision import datasets, transforms, models
from torchvision.models import (
    MobileNet_V3_Large_Weights,   # CHANGED: Large instead of Small
    EfficientNet_B0_Weights,
    ResNet18_Weights,
    DenseNet121_Weights
)
from torch.utils.data import DataLoader, Subset, WeightedRandomSampler
from pytorch_grad_cam import GradCAM
from pytorch_grad_cam.utils.image import show_cam_on_image
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget

def set_seed(seed=42):
    random.seed(seed); np.random.seed(seed)
    torch.manual_seed(seed); torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
set_seed(42)

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Device:", device)
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

BASE_PATH = "/kaggle/input/datasets/shifa199/rice-leaf-and-crop-disease-detection-dataset"
DATASET   = BASE_PATH
FILTERED  = "/kaggle/working/filtered_dataset"
OUT_DIR   = "/kaggle/working/paper_outputs"
for sub in ["", "/plots", "/gradcam", "/checkpoints"]:
    os.makedirs(OUT_DIR + sub, exist_ok=True)
print("Dataset folders:", os.listdir(DATASET))
# Out:
# Device: cuda
# GPU: Tesla T4
# Dataset folders: ['Tungro', 'Rice Blast', 'Healthy _leaf', 'Bacterial Leaf Blight', 'Rice']

# %%
BATCH_SIZE         = 32
CNN_EPOCHS         = 20
DL_EPOCHS          = 20
TRANSFORMER_EPOCHS = 30
PATIENCE           = 7
print(f"Batch:{BATCH_SIZE} | CNN:{CNN_EPOCHS} | DL:{DL_EPOCHS} | Transformer:{TRANSFORMER_EPOCHS} | Patience:{PATIENCE}")
# Out:
# Batch:32 | CNN:20 | DL:20 | Transformer:30 | Patience:7

# %%
classes_keep = ["Bacterial Leaf Blight", "Rice Blast", "Tungro", "Healthy _leaf"]
if os.path.exists(FILTERED): shutil.rmtree(FILTERED)
os.makedirs(FILTERED, exist_ok=True)
for c in classes_keep:
    src = os.path.join(DATASET, c)
    if os.path.exists(src):
        shutil.copytree(src, os.path.join(FILTERED, c), dirs_exist_ok=True)
        print(f"Copied: {c}")
    else:
        print(f"Missing: {src}")

from pathlib import Path
total, counts = 0, {}
for cls in classes_keep:
    imgs = (list(Path(FILTERED,cls).rglob("*.jpg")) +
            list(Path(FILTERED,cls).rglob("*.jpeg")) +
            list(Path(FILTERED,cls).rglob("*.png")))
    counts[cls] = len(imgs); total += len(imgs)
    print(f"  {cls:<25} -> {len(imgs):>5}")
ratio = counts[max(counts,key=counts.get)] / counts[min(counts,key=counts.get)]
print(f"  TOTAL: {total}  |  Imbalance ratio: {ratio:.2f}x")
# Out:
# Copied: Bacterial Leaf Blight
# Copied: Rice Blast
# Copied: Tungro
# Copied: Healthy _leaf
#   Bacterial Leaf Blight     ->   978
#   Rice Blast                ->  3343
#   Tungro                    ->  3745
#   Healthy _leaf             ->  1372
#   TOTAL: 9438  |  Imbalance ratio: 3.83x

# %%
train_tf = transforms.Compose([
    transforms.RandomResizedCrop(224, scale=(0.65, 1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.RandomRotation(20),
    transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225]),
    transforms.RandomErasing(p=0.2, scale=(0.02,0.15)),
])
test_tf = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225]),
])

# %%
dataset_full = datasets.ImageFolder(FILTERED, transform=train_tf)
targets = np.array(dataset_full.targets)
indices = np.arange(len(targets))
train_idx, temp_idx = train_test_split(indices,  test_size=0.2, stratify=targets,        random_state=42)
val_idx,   test_idx = train_test_split(temp_idx, test_size=0.5, stratify=targets[temp_idx], random_state=42)

train_dataset = datasets.ImageFolder(FILTERED, transform=train_tf)
val_dataset   = datasets.ImageFolder(FILTERED, transform=test_tf)
test_dataset  = datasets.ImageFolder(FILTERED, transform=test_tf)

train_ds = Subset(train_dataset, train_idx)
val_ds   = Subset(val_dataset,   val_idx)
test_ds  = Subset(test_dataset,  test_idx)

class_names = train_dataset.classes
num_classes = len(class_names)
print("Classes:", class_names)
print(f"Train:{len(train_ds)} | Val:{len(val_ds)} | Test:{len(test_ds)}")
# Out:
# Classes: ['Bacterial Leaf Blight', 'Healthy _leaf', 'Rice Blast', 'Tungro']
# Train:7550 | Val:944 | Test:944

# %%
train_targets = np.array([train_dataset.targets[i] for i in train_idx])
class_weights = compute_class_weight("balanced", classes=np.unique(train_targets), y=train_targets)
class_weights_tensor = torch.tensor(class_weights, dtype=torch.float).to(device)
print("Class weights:", class_weights_tensor)

sample_weights = torch.tensor([class_weights[t] for t in train_targets], dtype=torch.float)
sampler = WeightedRandomSampler(sample_weights, len(sample_weights), replacement=True)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, sampler=sampler,
                          num_workers=2, pin_memory=(device=="cuda"))
val_loader   = DataLoader(val_ds,   batch_size=BATCH_SIZE, shuffle=False,
                          num_workers=2, pin_memory=(device=="cuda"))
test_loader  = DataLoader(test_ds,  batch_size=BATCH_SIZE, shuffle=False,
                          num_workers=2, pin_memory=(device=="cuda"))

sampled = []
for i,(_, y) in enumerate(train_loader):
    sampled.extend(y.tolist())
    if i >= 100: break
c = Counter(sampled); total_s = sum(c.values())
print("Sampled distribution:")
for i, cls in enumerate(class_names):
    print(f"  {cls:<25} -> {c[i]:4d} ({c[i]/total_s:.3f})")
# Out:
# Class weights: tensor([2.4137, 1.7190, 0.7059, 0.6300], device='cuda:0')
# Sampled distribution:
#   Bacterial Leaf Blight     ->  802 (0.248)
#   Healthy _leaf             ->  789 (0.244)
#   Rice Blast                ->  827 (0.256)
#   Tungro                    ->  814 (0.252)

# %%
def train_model(model, train_loader, val_loader, class_weights_tensor, device,
                epochs=15, lr=3e-4, weight_decay=1e-4,
                checkpoint_path="/kaggle/working/best.pth",
                optimizer_type="adamw", scheduler_type="cosine",
                model_name="Model", patience=7):

    model.to(device)
    loss_fn   = nn.CrossEntropyLoss(weight=class_weights_tensor, label_smoothing=0.1)
    optimizer = (optim.AdamW if optimizer_type=="adamw" else optim.Adam)(
                    model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = (torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)
                 if scheduler_type=="cosine" else None)

    best_val_acc = 0.0; best_val_loss = float("inf"); no_improve = 0
    train_losses, val_losses = [], []
    print(f"\n{'='*60}\n  Training: {model_name}\n{'='*60}")

    for epoch in range(epochs):
        # ── Train
        model.train()
        run_loss = correct = total = 0
        bar = tqdm(train_loader, desc=f"Epoch {epoch+1:02d}/{epochs} [Train]", leave=False, ncols=85)
        for x, y in bar:
            x, y = x.to(device), y.to(device)
            optimizer.zero_grad()
            out = model(x)
            if out.dim()==4: out = out.mean(dim=[2,3])
            if out.dim()!=2: out = out.view(out.size(0),-1)
            loss = loss_fn(out, y)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()
            run_loss += loss.item(); correct += (out.argmax(1)==y).sum().item(); total += y.size(0)
            bar.set_postfix(loss=f"{loss.item():.4f}")

        epoch_loss = run_loss/len(train_loader); train_acc = correct/total
        train_losses.append(epoch_loss)

        # ── Validate
        model.eval(); v_correct = v_total = v_loss = 0
        with torch.no_grad():
            for x, y in val_loader:
                x, y = x.to(device), y.to(device)
                out = model(x)
                if out.dim()==4: out = out.mean(dim=[2,3])
                if out.dim()!=2: out = out.view(out.size(0),-1)
                v_loss    += loss_fn(out, y).item()
                v_correct += (out.argmax(1)==y).sum().item(); v_total += y.size(0)

        val_acc  = v_correct/v_total; val_loss = v_loss/len(val_loader)
        val_losses.append(val_loss)
        if scheduler: scheduler.step()

        flag   = "✅" if val_acc > best_val_acc else "  "
        cur_lr = optimizer.param_groups[0]["lr"]
        print(f"  Epoch {epoch+1:02d}/{epochs} | "
              f"Train Loss:{epoch_loss:.4f} Acc:{train_acc:.4f} | "
              f"Val Loss:{val_loss:.4f} Acc:{val_acc:.4f} | "
              f"LR:{cur_lr:.2e} {flag}")

        if val_acc > best_val_acc:
            best_val_acc = val_acc
            torch.save(model.state_dict(), checkpoint_path)

        if val_loss < best_val_loss - 1e-4:
            best_val_loss = val_loss; no_improve = 0
        else:
            no_improve += 1
            if no_improve >= patience:
                print(f"\n  ⛔ Early stopping at epoch {epoch+1}"); break

    print(f"\n  Best Val Acc: {best_val_acc:.4f} — restored from checkpoint")
    model.load_state_dict(torch.load(checkpoint_path, map_location=device))
    return model, train_losses, val_losses


def evaluate(model, loader, class_names, device):
    model.eval(); all_preds, all_labels = [], []
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device); out = model(x)
            if out.dim()==4: out = out.mean(dim=[2,3])
            if out.dim()!=2: out = out.view(out.size(0),-1)
            all_preds.extend(out.argmax(1).cpu().numpy()); all_labels.extend(y.numpy())
    report = classification_report(all_labels, all_preds,
                 target_names=class_names, output_dict=True, zero_division=0)
    return all_labels, all_preds, report, confusion_matrix(all_labels, all_preds)


def model_info(model, device):
    model.eval()
    params  = sum(p.numel() for p in model.parameters())
    size_mb = params*4/(1024**2)
    x = torch.randn(1,3,224,224).to(device)
    with torch.inference_mode():
        for _ in range(10): model(x)
        if device=="cuda": torch.cuda.synchronize()
        t0 = time.perf_counter()
        for _ in range(100): model(x)
        if device=="cuda": torch.cuda.synchronize()
        elapsed = time.perf_counter()-t0
    lat = elapsed/100
    return params, size_mb, lat, 1/lat

# %%
# ── MobileNetV3-Large
# CHANGE: Replaced MobileNetV3-Small (2.5M params, 67.7% ImageNet)
#         with MobileNetV3-Large (5.4M params, 74.0% ImageNet)
# WHY:    Small was architecturally too weak — val acc stuck at 41% across
#         multiple tuning attempts. Large has 2x the capacity and a stronger
#         feature extractor, while still being lightweight vs ResNet/DenseNet.
#
# FREEZE: Large has 17 feature layers (indices 0-16).
#         Freeze first 10, unfreeze last 7 (features[10:]).
#         This gives ~1.5M trainable params — enough to learn without overfitting.

model_mobilenet = models.mobilenet_v3_large(weights=MobileNet_V3_Large_Weights.DEFAULT)

# Freeze first 10 of 17 feature layers
for i, layer in enumerate(model_mobilenet.features):
    for p in layer.parameters():
        p.requires_grad = (i >= 10)

# classifier[3] is the final linear layer in MobileNetV3-Large (same structure as Small)
in_feat = model_mobilenet.classifier[3].in_features
model_mobilenet.classifier[3] = nn.Sequential(
    nn.Dropout(p=0.4),
    nn.Linear(in_feat, num_classes)
)

trainable = sum(p.numel() for p in model_mobilenet.parameters() if p.requires_grad)
print(f"MobileNetV3-Large — trainable params: {trainable:,}")

model_mobilenet, mobilenet_train_losses, mobilenet_val_losses = train_model(
    model_mobilenet, train_loader, val_loader, class_weights_tensor, device,
    epochs=CNN_EPOCHS, lr=3e-4, weight_decay=0.01,
    optimizer_type="adamw", scheduler_type="cosine",
    checkpoint_path=os.path.join(OUT_DIR,"checkpoints","mobilenet_best.pth"),
    model_name="MobileNetV3-Large", patience=PATIENCE
)
# Out:
# Downloading: "https://download.pytorch.org/models/mobilenet_v3_large-5c1a4163.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v3_large-5c1a4163.pth
# 100%|██████████| 21.1M/21.1M [00:00<00:00, 143MB/s]
# MobileNetV3-Large — trainable params: 4,047,204
#
# ============================================================
#   Training: MobileNetV3-Large
# ============================================================
#   Epoch 01/20 | Train Loss:0.7807 Acc:0.5862 | Val Loss:1.0782 Acc:0.4672 | LR:2.98e-04 ✅
#   Epoch 02/20 | Train Loss:0.6124 Acc:0.7483 | Val Loss:0.7790 Acc:0.7807 | LR:2.93e-04 ✅
#   Epoch 03/20 | Train Loss:0.5728 Acc:0.8012 | Val Loss:0.7284 Acc:0.8252 | LR:2.84e-04 ✅
#   Epoch 04/20 | Train Loss:0.5272 Acc:0.8391 | Val Loss:0.7488 Acc:0.8252 | LR:2.71e-04
#   Epoch 05/20 | Train Loss:0.4995 Acc:0.8672 | Val Loss:0.6947 Acc:0.8686 | LR:2.56e-04 ✅
#   Epoch 06/20 | Train Loss:0.4816 Acc:0.8824 | Val Loss:0.6743 Acc:0.8835 | LR:2.38e-04 ✅
#   Epoch 07/20 | Train Loss:0.4709 Acc:0.8934 | Val Loss:0.7053 Acc:0.8538 | LR:2.18e-04
#   Epoch 08/20 | Train Loss:0.4615 Acc:0.8980 | Val Loss:0.6586 Acc:0.8814 | LR:1.96e-04
#   Epoch 09/20 | Train Loss:0.4459 Acc:0.9136 | Val Loss:0.6668 Acc:0.8867 | LR:1.73e-04 ✅
#   Epoch 10/20 | Train Loss:0.4407 Acc:0.9135 | Val Loss:0.6414 Acc:0.8962 | LR:1.50e-04 ✅
#   Epoch 11/20 | Train Loss:0.4376 Acc:0.9211 | Val Loss:0.6249 Acc:0.9057 | LR:1.27e-04 ✅
#   Epoch 12/20 | Train Loss:0.4322 Acc:0.9257 | Val Loss:0.6144 Acc:0.9174 | LR:1.04e-04 ✅
#   Epoch 13/20 | Train Loss:0.4205 Acc:0.9363 | Val Loss:0.6315 Acc:0.9110 | LR:8.19e-05
#   Epoch 14/20 | Train Loss:0.4163 Acc:0.9376 | Val Loss:0.6328 Acc:0.9015 | LR:6.18e-05
#   Epoch 15/20 | Train Loss:0.4109 Acc:0.9384 | Val Loss:0.6240 Acc:0.9153 | LR:4.39e-05
#   Epoch 16/20 | Train Loss:0.4078 Acc:0.9416 | Val Loss:0.6141 Acc:0.9184 | LR:2.86e-05 ✅
#   Epoch 17/20 | Train Loss:0.4170 Acc:0.9328 | Val Loss:0.6129 Acc:0.9121 | LR:1.63e-05
#   Epoch 18/20 | Train Loss:0.4112 Acc:0.9409 | Val Loss:0.6074 Acc:0.9174 | LR:7.34e-06
#   Epoch 19/20 | Train Loss:0.4059 Acc:0.9419 | Val Loss:0.6136 Acc:0.9184 | LR:1.85e-06
#   Epoch 20/20 | Train Loss:0.4065 Acc:0.9428 | Val Loss:0.6124 Acc:0.9174 | LR:0.00e+00
#
#   Best Val Acc: 0.9184 — restored from checkpoint

# %%
# ── EfficientNetB0
# Unfreeze features[6:] (last 3 of 9 blocks), Dropout 0.40
model_eff = models.efficientnet_b0(weights=EfficientNet_B0_Weights.DEFAULT)

for i, block in enumerate(model_eff.features):
    for p in block.parameters():
        p.requires_grad = (i >= 6)

in_feat = model_eff.classifier[1].in_features
model_eff.classifier[1] = nn.Sequential(
    nn.Dropout(p=0.40),
    nn.Linear(in_feat, num_classes)
)

trainable = sum(p.numel() for p in model_eff.parameters() if p.requires_grad)
print(f"EfficientNetB0 — trainable params: {trainable:,}")

model_eff, eff_train_losses, eff_val_losses = train_model(
    model_eff, train_loader, val_loader, class_weights_tensor, device,
    epochs=CNN_EPOCHS, lr=3e-4, weight_decay=0.01,
    optimizer_type="adamw", scheduler_type="cosine",
    checkpoint_path=os.path.join(OUT_DIR,"checkpoints","efficientnet_best.pth"),
    model_name="EfficientNetB0", patience=PATIENCE
)
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 133MB/s]
# EfficientNetB0 — trainable params: 3,160,864
#
# ============================================================
#   Training: EfficientNetB0
# ============================================================
#   Epoch 01/20 | Train Loss:0.8390 Acc:0.5420 | Val Loss:0.9905 Acc:0.5318 | LR:2.98e-04 ✅
#   Epoch 02/20 | Train Loss:0.6916 Acc:0.6764 | Val Loss:0.9522 Acc:0.5964 | LR:2.93e-04 ✅
#   Epoch 03/20 | Train Loss:0.6585 Acc:0.7066 | Val Loss:0.8487 Acc:0.7182 | LR:2.84e-04 ✅
#   Epoch 04/20 | Train Loss:0.6121 Acc:0.7527 | Val Loss:0.7992 Acc:0.7680 | LR:2.71e-04 ✅
#   Epoch 05/20 | Train Loss:0.5993 Acc:0.7728 | Val Loss:0.7642 Acc:0.7956 | LR:2.56e-04 ✅
#   Epoch 06/20 | Train Loss:0.5606 Acc:0.8007 | Val Loss:0.7343 Acc:0.8464 | LR:2.38e-04 ✅
#   Epoch 07/20 | Train Loss:0.5543 Acc:0.8147 | Val Loss:0.7402 Acc:0.8422 | LR:2.18e-04
#   Epoch 08/20 | Train Loss:0.5343 Acc:0.8328 | Val Loss:0.7644 Acc:0.8114 | LR:1.96e-04
#   Epoch 09/20 | Train Loss:0.5242 Acc:0.8510 | Val Loss:0.7065 Acc:0.8644 | LR:1.73e-04 ✅
#   Epoch 10/20 | Train Loss:0.5164 Acc:0.8535 | Val Loss:0.7188 Acc:0.8559 | LR:1.50e-04
#   Epoch 11/20 | Train Loss:0.5116 Acc:0.8596 | Val Loss:0.6744 Acc:0.8792 | LR:1.27e-04 ✅
#   Epoch 12/20 | Train Loss:0.4882 Acc:0.8763 | Val Loss:0.6939 Acc:0.8771 | LR:1.04e-04
#   Epoch 13/20 | Train Loss:0.4896 Acc:0.8797 | Val Loss:0.6808 Acc:0.8750 | LR:8.19e-05
#   Epoch 14/20 | Train Loss:0.4820 Acc:0.8775 | Val Loss:0.6657 Acc:0.8909 | LR:6.18e-05 ✅
#   Epoch 15/20 | Train Loss:0.4807 Acc:0.8858 | Val Loss:0.6589 Acc:0.8941 | LR:4.39e-05 ✅
#   Epoch 16/20 | Train Loss:0.4790 Acc:0.8873 | Val Loss:0.6724 Acc:0.8941 | LR:2.86e-05
#   Epoch 17/20 | Train Loss:0.4733 Acc:0.8866 | Val Loss:0.6643 Acc:0.8951 | LR:1.63e-05 ✅
#   Epoch 18/20 | Train Loss:0.4748 Acc:0.8921 | Val Loss:0.6608 Acc:0.8930 | LR:7.34e-06
#   Epoch 19/20 | Train Loss:0.4647 Acc:0.8951 | Val Loss:0.6619 Acc:0.8983 | LR:1.85e-06 ✅
#   Epoch 20/20 | Train Loss:0.4617 Acc:0.9000 | Val Loss:0.6548 Acc:0.9004 | LR:0.00e+00 ✅
#
#   Best Val Acc: 0.9004 — restored from checkpoint

# %%
# ── ResNet18
# Unfreeze all of layer4 (both blocks), weight_decay 0.02
model_resnet = models.resnet18(weights=ResNet18_Weights.DEFAULT)

for name, p in model_resnet.named_parameters():
    p.requires_grad = (name.startswith("layer4") or name.startswith("fc"))

in_feat = model_resnet.fc.in_features
model_resnet.fc = nn.Sequential(
    nn.BatchNorm1d(in_feat),
    nn.Dropout(p=0.45),
    nn.Linear(in_feat, num_classes)
)

trainable = sum(p.numel() for p in model_resnet.parameters() if p.requires_grad)
print(f"ResNet18 — trainable params: {trainable:,}")

model_resnet, resnet_train_losses, resnet_val_losses = train_model(
    model_resnet, train_loader, val_loader, class_weights_tensor, device,
    epochs=DL_EPOCHS, lr=3e-4, weight_decay=0.02,
    optimizer_type="adamw", scheduler_type="cosine",
    checkpoint_path=os.path.join(OUT_DIR,"checkpoints","resnet18_best.pth"),
    model_name="ResNet18", patience=PATIENCE
)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 192MB/s]
# ResNet18 — trainable params: 8,396,804
#
# ============================================================
#   Training: ResNet18
# ============================================================
#   Epoch 01/20 | Train Loss:0.9422 Acc:0.5673 | Val Loss:1.0594 Acc:0.5593 | LR:2.98e-04 ✅
#   Epoch 02/20 | Train Loss:0.7868 Acc:0.6211 | Val Loss:1.0517 Acc:0.5275 | LR:2.93e-04
#   Epoch 03/20 | Train Loss:0.7366 Acc:0.6580 | Val Loss:0.9590 Acc:0.5657 | LR:2.84e-04 ✅
#   Epoch 04/20 | Train Loss:0.6998 Acc:0.6894 | Val Loss:0.9437 Acc:0.6133 | LR:2.71e-04 ✅
#   Epoch 05/20 | Train Loss:0.6749 Acc:0.7032 | Val Loss:0.9365 Acc:0.6568 | LR:2.56e-04 ✅
#   Epoch 06/20 | Train Loss:0.6552 Acc:0.7256 | Val Loss:0.8468 Acc:0.7722 | LR:2.38e-04 ✅
#   Epoch 07/20 | Train Loss:0.6270 Acc:0.7444 | Val Loss:0.8853 Acc:0.7023 | LR:2.18e-04
#   Epoch 08/20 | Train Loss:0.6143 Acc:0.7542 | Val Loss:0.8876 Acc:0.6706 | LR:1.96e-04
#   Epoch 09/20 | Train Loss:0.6022 Acc:0.7779 | Val Loss:0.8400 Acc:0.7044 | LR:1.73e-04
#   Epoch 10/20 | Train Loss:0.5789 Acc:0.7878 | Val Loss:0.7908 Acc:0.7648 | LR:1.50e-04
#   Epoch 11/20 | Train Loss:0.5814 Acc:0.7894 | Val Loss:0.7839 Acc:0.8178 | LR:1.27e-04 ✅
#   Epoch 12/20 | Train Loss:0.5632 Acc:0.8091 | Val Loss:0.8049 Acc:0.7383 | LR:1.04e-04
#   Epoch 13/20 | Train Loss:0.5547 Acc:0.8204 | Val Loss:0.7625 Acc:0.7977 | LR:8.19e-05
#   Epoch 14/20 | Train Loss:0.5431 Acc:0.8339 | Val Loss:0.7632 Acc:0.7881 | LR:6.18e-05
#   Epoch 15/20 | Train Loss:0.5294 Acc:0.8358 | Val Loss:0.7321 Acc:0.8400 | LR:4.39e-05 ✅
#   Epoch 16/20 | Train Loss:0.5383 Acc:0.8356 | Val Loss:0.7413 Acc:0.8167 | LR:2.86e-05
#   Epoch 17/20 | Train Loss:0.5241 Acc:0.8518 | Val Loss:0.7315 Acc:0.8369 | LR:1.63e-05
#   Epoch 18/20 | Train Loss:0.5171 Acc:0.8485 | Val Loss:0.7231 Acc:0.8369 | LR:7.34e-06
#   Epoch 19/20 | Train Loss:0.5225 Acc:0.8437 | Val Loss:0.7259 Acc:0.8220 | LR:1.85e-06
#   Epoch 20/20 | Train Loss:0.5086 Acc:0.8576 | Val Loss:0.7264 Acc:0.8305 | LR:0.00e+00
#
#   Best Val Acc: 0.8400 — restored from checkpoint

# %%
# ── DenseNet121
# Unfreeze last 3 denselayers (14,15,16) + norm5, weight_decay 0.02
model_densenet = models.densenet121(weights=DenseNet121_Weights.DEFAULT)

for p in model_densenet.parameters():
    p.requires_grad = False

for name, p in model_densenet.named_parameters():
    if (any(f"denseblock4.denselayer{k}" in name for k in [14,15,16]) or
        "features.norm5" in name or name.startswith("classifier")):
        p.requires_grad = True

in_feat = model_densenet.classifier.in_features
model_densenet.classifier = nn.Sequential(
    nn.BatchNorm1d(in_feat),
    nn.Dropout(p=0.45),
    nn.Linear(in_feat, num_classes)
)

trainable = sum(p.numel() for p in model_densenet.parameters() if p.requires_grad)
print(f"DenseNet121 — trainable params: {trainable:,}")

model_densenet, densenet_train_losses, densenet_val_losses = train_model(
    model_densenet, train_loader, val_loader, class_weights_tensor, device,
    epochs=DL_EPOCHS, lr=3e-4, weight_decay=0.02,
    optimizer_type="adamw", scheduler_type="cosine",
    checkpoint_path=os.path.join(OUT_DIR,"checkpoints","densenet121_best.pth"),
    model_name="DenseNet121", patience=PATIENCE
)
# Out:
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/hub/checkpoints/densenet121-a639ec97.pth
# 100%|██████████| 30.8M/30.8M [00:00<00:00, 160MB/s]
# DenseNet121 — trainable params: 493,956
#
# ============================================================
#   Training: DenseNet121
# ============================================================
#   Epoch 01/20 | Train Loss:0.9841 Acc:0.5122 | Val Loss:1.1509 Acc:0.4110 | LR:2.98e-04 ✅
#   Epoch 02/20 | Train Loss:0.7897 Acc:0.6015 | Val Loss:0.9798 Acc:0.5879 | LR:2.93e-04 ✅
#   Epoch 03/20 | Train Loss:0.7461 Acc:0.6404 | Val Loss:0.9452 Acc:0.6208 | LR:2.84e-04 ✅
#   Epoch 04/20 | Train Loss:0.7212 Acc:0.6652 | Val Loss:0.9353 Acc:0.6536 | LR:2.71e-04 ✅
#   Epoch 05/20 | Train Loss:0.6932 Acc:0.6846 | Val Loss:0.9472 Acc:0.6398 | LR:2.56e-04
#   Epoch 06/20 | Train Loss:0.6770 Acc:0.6988 | Val Loss:0.9505 Acc:0.6748 | LR:2.38e-04 ✅
#   Epoch 07/20 | Train Loss:0.6544 Acc:0.7279 | Val Loss:0.8626 Acc:0.7097 | LR:2.18e-04 ✅
#   Epoch 08/20 | Train Loss:0.6515 Acc:0.7313 | Val Loss:0.8722 Acc:0.6769 | LR:1.96e-04
#   Epoch 09/20 | Train Loss:0.6436 Acc:0.7351 | Val Loss:0.8513 Acc:0.6939 | LR:1.73e-04
#   Epoch 10/20 | Train Loss:0.6382 Acc:0.7450 | Val Loss:0.8516 Acc:0.7044 | LR:1.50e-04
#   Epoch 11/20 | Train Loss:0.6275 Acc:0.7560 | Val Loss:0.9043 Acc:0.6769 | LR:1.27e-04
#   Epoch 12/20 | Train Loss:0.6090 Acc:0.7660 | Val Loss:0.8506 Acc:0.7299 | LR:1.04e-04 ✅
#   Epoch 13/20 | Train Loss:0.6186 Acc:0.7690 | Val Loss:0.8563 Acc:0.7256 | LR:8.19e-05
#   Epoch 14/20 | Train Loss:0.6070 Acc:0.7638 | Val Loss:0.8409 Acc:0.7426 | LR:6.18e-05 ✅
#   Epoch 15/20 | Train Loss:0.6025 Acc:0.7796 | Val Loss:0.8481 Acc:0.7161 | LR:4.39e-05
#   Epoch 16/20 | Train Loss:0.5979 Acc:0.7849 | Val Loss:0.8408 Acc:0.7267 | LR:2.86e-05
#   Epoch 17/20 | Train Loss:0.5935 Acc:0.7770 | Val Loss:0.8295 Acc:0.7235 | LR:1.63e-05
#   Epoch 18/20 | Train Loss:0.5895 Acc:0.7832 | Val Loss:0.8198 Acc:0.7394 | LR:7.34e-06
#   Epoch 19/20 | Train Loss:0.6002 Acc:0.7824 | Val Loss:0.8128 Acc:0.7553 | LR:1.85e-06 ✅
#   Epoch 20/20 | Train Loss:0.5904 Acc:0.7820 | Val Loss:0.8369 Acc:0.7214 | LR:0.00e+00
#
#   Best Val Acc: 0.7553 — restored from checkpoint

# %%
# ── ViT-Tiny
# Freeze only first 4 blocks, drop_path 0.10, lr 5e-5, weight_decay 0.05
model_vit = timm.create_model(
    "vit_tiny_patch16_224",
    pretrained=True, num_classes=num_classes,
    drop_path_rate=0.10,
    drop_rate=0.10
)

for i, block in enumerate(model_vit.blocks):
    for p in block.parameters():
        p.requires_grad = (i >= 4)

for p in model_vit.patch_embed.parameters():
    p.requires_grad = False

trainable = sum(p.numel() for p in model_vit.parameters() if p.requires_grad)
print(f"ViT-Tiny — trainable params: {trainable:,}")

model_vit, vit_train_losses, vit_val_losses = train_model(
    model_vit, train_loader, val_loader, class_weights_tensor, device,
    epochs=TRANSFORMER_EPOCHS, lr=5e-5, weight_decay=0.05,
    optimizer_type="adamw", scheduler_type="cosine",
    checkpoint_path=os.path.join(OUT_DIR,"checkpoints","vit_best.pth"),
    model_name="ViT-Tiny", patience=PATIENCE
)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/22.9M [00:00<?, ?B/s]
# ViT-Tiny — trainable params: 3,598,084
#
# ============================================================
#   Training: ViT-Tiny
# ============================================================
#   Epoch 01/30 | Train Loss:1.0088 Acc:0.4555 | Val Loss:1.0125 Acc:0.4894 | LR:4.99e-05 ✅
#   Epoch 02/30 | Train Loss:0.7970 Acc:0.5842 | Val Loss:0.9358 Acc:0.5551 | LR:4.95e-05 ✅
#   Epoch 03/30 | Train Loss:0.7359 Acc:0.6330 | Val Loss:0.8712 Acc:0.6388 | LR:4.88e-05 ✅
#   Epoch 04/30 | Train Loss:0.6987 Acc:0.6632 | Val Loss:0.9017 Acc:0.6070 | LR:4.78e-05
#   Epoch 05/30 | Train Loss:0.6839 Acc:0.6742 | Val Loss:0.8689 Acc:0.6261 | LR:4.67e-05
#   Epoch 06/30 | Train Loss:0.6499 Acc:0.6883 | Val Loss:0.8422 Acc:0.6737 | LR:4.52e-05 ✅
#   Epoch 07/30 | Train Loss:0.6717 Acc:0.6903 | Val Loss:0.8567 Acc:0.6758 | LR:4.36e-05 ✅
#   Epoch 08/30 | Train Loss:0.6468 Acc:0.7077 | Val Loss:0.8414 Acc:0.6833 | LR:4.17e-05 ✅
#   Epoch 09/30 | Train Loss:0.6229 Acc:0.7348 | Val Loss:0.7919 Acc:0.7691 | LR:3.97e-05 ✅
#   Epoch 10/30 | Train Loss:0.6252 Acc:0.7307 | Val Loss:0.7676 Acc:0.7669 | LR:3.75e-05
#   Epoch 11/30 | Train Loss:0.6012 Acc:0.7562 | Val Loss:0.7589 Acc:0.8125 | LR:3.52e-05 ✅
#   Epoch 12/30 | Train Loss:0.6017 Acc:0.7532 | Val Loss:0.7383 Acc:0.8083 | LR:3.27e-05
#   Epoch 13/30 | Train Loss:0.5873 Acc:0.7702 | Val Loss:0.7591 Acc:0.7712 | LR:3.02e-05
#   Epoch 14/30 | Train Loss:0.5756 Acc:0.7793 | Val Loss:0.7480 Acc:0.7903 | LR:2.76e-05
#   Epoch 15/30 | Train Loss:0.5717 Acc:0.7804 | Val Loss:0.7395 Acc:0.8125 | LR:2.50e-05
#   Epoch 16/30 | Train Loss:0.5694 Acc:0.7906 | Val Loss:0.7560 Acc:0.7807 | LR:2.24e-05
#   Epoch 17/30 | Train Loss:0.5608 Acc:0.8012 | Val Loss:0.7514 Acc:0.7850 | LR:1.98e-05
#   Epoch 18/30 | Train Loss:0.5589 Acc:0.7947 | Val Loss:0.7211 Acc:0.8284 | LR:1.73e-05 ✅
#   Epoch 19/30 | Train Loss:0.5538 Acc:0.8110 | Val Loss:0.6940 Acc:0.8570 | LR:1.48e-05 ✅
#   Epoch 20/30 | Train Loss:0.5487 Acc:0.8143 | Val Loss:0.7301 Acc:0.8104 | LR:1.25e-05
#   Epoch 21/30 | Train Loss:0.5396 Acc:0.8183 | Val Loss:0.7020 Acc:0.8453 | LR:1.03e-05
#   Epoch 22/30 | Train Loss:0.5425 Acc:0.8171 | Val Loss:0.7021 Acc:0.8453 | LR:8.27e-06
#   Epoch 23/30 | Train Loss:0.5350 Acc:0.8148 | Val Loss:0.7031 Acc:0.8422 | LR:6.42e-06
#   Epoch 24/30 | Train Loss:0.5409 Acc:0.8207 | Val Loss:0.6965 Acc:0.8411 | LR:4.77e-06
#   Epoch 25/30 | Train Loss:0.5374 Acc:0.8265 | Val Loss:0.7150 Acc:0.8358 | LR:3.35e-06
#   Epoch 26/30 | Train Loss:0.5213 Acc:0.8319 | Val Loss:0.7040 Acc:0.8390 | LR:2.16e-06
#
#   ⛔ Early stopping at epoch 26
#
#   Best Val Acc: 0.8570 — restored from checkpoint

# %%
# ── Cell 15 — Train Transformer: Swin-Tiny
class_weights_tensor = torch.tensor(
    compute_class_weight(
        class_weight="balanced",
        classes=np.arange(num_classes),
        y=np.array([train_dataset.targets[i] for i in train_idx])
    ),
    dtype=torch.float
).to(device)

# FIX 1: drop_path_rate=0.2 adds stochastic depth (stronger than ViT
#         because Swin has more blocks)
model_swin = timm.create_model(
    "swin_tiny_patch4_window7_224",
    pretrained=True,
    num_classes=0,
    drop_path_rate=0.2     # FIX: stochastic depth
)
in_features = model_swin.num_features

class SwinClassifier(nn.Module):
    def __init__(self, backbone, in_features, num_classes):
        super().__init__()
        self.backbone = backbone
        # FIX 2: Increased Dropout from 0.3 to 0.4 for consistency
        self.dropout  = nn.Dropout(p=0.4)
        self.fc       = nn.Linear(in_features, num_classes)

    def forward(self, x):
        x = self.backbone(x)
        if x.dim() == 4:
            x = x.mean(dim=[2, 3])
        elif x.dim() == 3:
            x = x.mean(dim=1)
        x = self.dropout(x)
        return self.fc(x)

model_swin = SwinClassifier(model_swin, in_features, num_classes)
model_swin.to(device)

with torch.no_grad():
    dummy = torch.randn(2, 3, 224, 224).to(device)
    out   = model_swin(dummy)
    print(f"Swin output shape: {out.shape}")

model_swin, swin_train_losses, swin_val_losses = train_model(
    model_swin, train_loader, val_loader,
    class_weights_tensor, device,
    epochs=TRANSFORMER_EPOCHS,
    lr=5e-5,               # FIX: lower lr — same as ViT
    weight_decay=0.05,
    optimizer_type="adamw",
    scheduler_type="cosine",
    checkpoint_path=os.path.join(OUT_DIR, "checkpoints", "swin_best.pth"),
    model_name="Swin-Tiny",
    patience=PATIENCE
)
# Out:
# model.safetensors:   0%|          | 0.00/114M [00:00<?, ?B/s]
# Swin output shape: torch.Size([2, 4])
#
# ============================================================
#   Training: Swin-Tiny
# ============================================================
#   Epoch 01/30 | Train Loss:0.8336 Acc:0.5426 | Val Loss:0.9842 Acc:0.5487 | LR:4.99e-05 ✅
#   Epoch 02/30 | Train Loss:0.6631 Acc:0.6968 | Val Loss:0.9764 Acc:0.5742 | LR:4.95e-05 ✅
#   Epoch 03/30 | Train Loss:0.6066 Acc:0.7604 | Val Loss:0.7662 Acc:0.7733 | LR:4.88e-05 ✅
#   Epoch 04/30 | Train Loss:0.5594 Acc:0.8103 | Val Loss:0.7681 Acc:0.7712 | LR:4.78e-05
#   Epoch 05/30 | Train Loss:0.5292 Acc:0.8381 | Val Loss:0.7571 Acc:0.8019 | LR:4.67e-05 ✅
#   Epoch 06/30 | Train Loss:0.5065 Acc:0.8554 | Val Loss:0.7311 Acc:0.8294 | LR:4.52e-05 ✅
#   Epoch 07/30 | Train Loss:0.4956 Acc:0.8739 | Val Loss:0.6694 Acc:0.8633 | LR:4.36e-05 ✅
#   Epoch 08/30 | Train Loss:0.4780 Acc:0.8817 | Val Loss:0.6734 Acc:0.8792 | LR:4.17e-05 ✅
#   Epoch 09/30 | Train Loss:0.4628 Acc:0.8955 | Val Loss:0.6914 Acc:0.8718 | LR:3.97e-05
#   Epoch 10/30 | Train Loss:0.4555 Acc:0.9069 | Val Loss:0.6613 Acc:0.8962 | LR:3.75e-05 ✅
#   Epoch 11/30 | Train Loss:0.4494 Acc:0.9094 | Val Loss:0.6733 Acc:0.8835 | LR:3.52e-05
#   Epoch 12/30 | Train Loss:0.4461 Acc:0.9147 | Val Loss:0.6717 Acc:0.8792 | LR:3.27e-05
#   Epoch 13/30 | Train Loss:0.4401 Acc:0.9193 | Val Loss:0.6320 Acc:0.9089 | LR:3.02e-05 ✅
#   Epoch 14/30 | Train Loss:0.4286 Acc:0.9282 | Val Loss:0.6429 Acc:0.9025 | LR:2.76e-05
#   Epoch 15/30 | Train Loss:0.4194 Acc:0.9332 | Val Loss:0.6441 Acc:0.9004 | LR:2.50e-05
#   Epoch 16/30 | Train Loss:0.4175 Acc:0.9330 | Val Loss:0.6318 Acc:0.9047 | LR:2.24e-05
#   Epoch 17/30 | Train Loss:0.4230 Acc:0.9297 | Val Loss:0.6285 Acc:0.9057 | LR:1.98e-05
#   Epoch 18/30 | Train Loss:0.4131 Acc:0.9354 | Val Loss:0.6417 Acc:0.8983 | LR:1.73e-05
#   Epoch 19/30 | Train Loss:0.4141 Acc:0.9362 | Val Loss:0.6369 Acc:0.9047 | LR:1.48e-05
#   Epoch 20/30 | Train Loss:0.4166 Acc:0.9375 | Val Loss:0.6212 Acc:0.9110 | LR:1.25e-05 ✅
#   Epoch 21/30 | Train Loss:0.4131 Acc:0.9383 | Val Loss:0.6292 Acc:0.9110 | LR:1.03e-05
#   Epoch 22/30 | Train Loss:0.4149 Acc:0.9384 | Val Loss:0.6205 Acc:0.9153 | LR:8.27e-06 ✅
#   Epoch 23/30 | Train Loss:0.4093 Acc:0.9438 | Val Loss:0.6214 Acc:0.9089 | LR:6.42e-06
#   Epoch 24/30 | Train Loss:0.3995 Acc:0.9489 | Val Loss:0.6230 Acc:0.9100 | LR:4.77e-06
#   Epoch 25/30 | Train Loss:0.4122 Acc:0.9415 | Val Loss:0.6189 Acc:0.9100 | LR:3.35e-06
#   Epoch 26/30 | Train Loss:0.4002 Acc:0.9458 | Val Loss:0.6203 Acc:0.9121 | LR:2.16e-06
#   Epoch 27/30 | Train Loss:0.4008 Acc:0.9482 | Val Loss:0.6216 Acc:0.9142 | LR:1.22e-06
#   Epoch 28/30 | Train Loss:0.3963 Acc:0.9495 | Val Loss:0.6217 Acc:0.9153 | LR:5.46e-07
#   Epoch 29/30 | Train Loss:0.4081 Acc:0.9440 | Val Loss:0.6197 Acc:0.9153 | LR:1.37e-07
#   Epoch 30/30 | Train Loss:0.4005 Acc:0.9477 | Val Loss:0.6199 Acc:0.9163 | LR:0.00e+00 ✅
#
#   Best Val Acc: 0.9163 — restored from checkpoint

# %%
all_models = {
    "MobileNetV3-Large": model_mobilenet,
    "EfficientNetB0":    model_eff,
    "ResNet18":          model_resnet,
    "DenseNet121":       model_densenet,
    "ViT-Tiny":          model_vit,
    "Swin-Tiny":         model_swin
}
all_reports, all_model_metrics = {}, {}

for name, model in all_models.items():
    print(f"\nEvaluating {name}...")
    labels, preds, report, cm     = evaluate(model, test_loader, class_names, device)
    params, size_mb, latency, fps = model_info(model, device)
    all_reports[name] = report
    all_model_metrics[name] = {
        "accuracy":           report["accuracy"],
        "precision_weighted": report["weighted avg"]["precision"],
        "recall_weighted":    report["weighted avg"]["recall"],
        "weighted_f1":        report["weighted avg"]["f1-score"],
        "macro_f1":           report["macro avg"]["f1-score"],
        "params_M":           round(params/1e6,2),
        "size_mb":            size_mb,
        "latency_ms":         latency*1000,
        "fps":                fps,
        "cm":                 cm
    }
    print(f"  Acc:{report['accuracy']:.4f} | W-F1:{report['weighted avg']['f1-score']:.4f} | "
          f"Params:{round(params/1e6,2)}M | Latency:{latency*1000:.2f}ms")

plot_models = list(all_models.keys())
summary_df = pd.DataFrame(all_model_metrics).T[[
    "accuracy","precision_weighted","recall_weighted","weighted_f1",
    "macro_f1","params_M","size_mb","latency_ms","fps"
]].loc[plot_models]
print("\n=== Summary Table ===")
display(summary_df)
summary_df.to_csv(os.path.join(OUT_DIR,"model_summary_results.csv"))
# Out:
# Evaluating MobileNetV3-Large...
#   Acc:0.9333 | W-F1:0.9355 | Params:4.21M | Latency:5.75ms
#
# Evaluating EfficientNetB0...
#   Acc:0.9153 | W-F1:0.9185 | Params:4.01M | Latency:7.77ms
#
# Evaluating ResNet18...
#   Acc:0.8506 | W-F1:0.8539 | Params:11.18M | Latency:2.84ms
#
# Evaluating DenseNet121...
#   Acc:0.7669 | W-F1:0.7795 | Params:6.96M | Latency:13.74ms
#
# Evaluating ViT-Tiny...
#   Acc:0.8379 | W-F1:0.8444 | Params:5.53M | Latency:4.29ms
#
# Evaluating Swin-Tiny...
#   Acc:0.9311 | W-F1:0.9326 | Params:27.52M | Latency:9.64ms
#
# === Summary Table ===
#                    accuracy precision_weighted recall_weighted weighted_f1  \
# MobileNetV3-Large  0.933263           0.946479        0.933263    0.935473
# EfficientNetB0     0.915254           0.934828        0.915254    0.918473
# ResNet18           0.850636           0.877868        0.850636    0.853921
# DenseNet121        0.766949           0.848836        0.766949    0.779469
# ViT-Tiny           0.837924           0.874415        0.837924    0.844409
# Swin-Tiny          0.931144           0.942229        0.931144    0.932607
#
#                    macro_f1 params_M     size_mb latency_ms         fps
# MobileNetV3-Large  0.916111     4.21   16.049026   5.754168  173.787079
# EfficientNetB0     0.897521     4.01   15.307129   7.772437   128.65978
# ResNet18           0.838832    11.18   42.646744   2.837843  352.380313
# DenseNet121        0.758233     6.96   26.550308  13.736577   72.798341
# ViT-Tiny           0.822983     5.53    21.07692   4.290392  233.078952
# Swin-Tiny           0.91583    27.52  104.989738   9.642953   103.70267

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report

# ── Identify best model
all_models = {
    "MobileNetV3-Large": model_mobilenet,
    "EfficientNetB0":    model_eff,
    "ResNet18":          model_resnet,
    "DenseNet121":       model_densenet,
    "ViT-Tiny":          model_vit,
    "Swin-Tiny":         model_swin,
}

best_name  = max(all_model_metrics, key=lambda k: all_model_metrics[k]["accuracy"])
best_model = all_models[best_name]
best_acc   = all_model_metrics[best_name]["accuracy"]
print(f"Best model: {best_name}  (Test Acc: {best_acc:.4f})")

# ── Re-evaluate on test set
best_model.eval()
all_preds, all_labels = [], []
with torch.no_grad():
    for x, y in test_loader:
        x = x.to(device)
        out = best_model(x)
        if out.dim() == 4: out = out.mean(dim=[2,3])
        if out.dim() != 2: out = out.view(out.size(0), -1)
        all_preds.extend(out.argmax(1).cpu().numpy())
        all_labels.extend(y.numpy())

cm = confusion_matrix(all_labels, all_preds)
report = classification_report(all_labels, all_preds,
             target_names=class_names, zero_division=0)
print("\n" + report)

# ── Plot
short_labels = ["BLB", "HL", "RB", "TU"]
fig, ax = plt.subplots(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=short_labels, yticklabels=short_labels,
            ax=ax, annot_kws={"size": 12}, linewidths=0.5)
ax.set_title(f"Confusion Matrix — {best_name}",
             fontsize=12, fontweight='bold', pad=10)
ax.set_xlabel("Predicted", fontsize=10)
ax.set_ylabel("Actual",    fontsize=10)
ax.tick_params(axis='x', labelsize=9)
ax.tick_params(axis='y', labelsize=9, rotation=0)
plt.figtext(0.5, 0.01,
    "BLB=Bacterial Leaf Blight | HL=Healthy Leaf | RB=Rice Blast | TU=Tungro",
    ha='center', fontsize=8, style='italic')
plt.tight_layout()
base = os.path.join(OUT_DIR, "plots", f"confusion_matrix_best_{best_name.replace(' ','_')}")
fig.savefig(base+".png", dpi=300, bbox_inches="tight")
fig.savefig(base+".pdf",           bbox_inches="tight")
print(f"\n  saved -> {base}.png")
plt.show()
# Out:
# Best model: MobileNetV3-Large  (Test Acc: 0.9333)
#
#                        precision    recall  f1-score   support
#
# Bacterial Leaf Blight       0.69      0.97      0.81        98
#         Healthy _leaf       0.94      1.00      0.97       137
#            Rice Blast       0.99      0.85      0.92       335
#                Tungro       0.98      0.97      0.97       374
#
#              accuracy                           0.93       944
#             macro avg       0.90      0.95      0.92       944
#          weighted avg       0.95      0.93      0.94       944
#
#
#   saved -> /kaggle/working/paper_outputs/plots/confusion_matrix_best_MobileNetV3-Large.png

# %%
# ── Swin-Tiny Confusion Matrix ──
swin_name  = "Swin-Tiny"
swin_model = all_models[swin_name]
swin_acc   = all_model_metrics[swin_name]["accuracy"]

swin_model.eval()
all_preds, all_labels = [], []
with torch.no_grad():
    for x, y in test_loader:
        x = x.to(device)
        out = swin_model(x)
        if out.dim() == 4: out = out.mean(dim=[2,3])
        if out.dim() != 2: out = out.view(out.size(0), -1)
        all_preds.extend(out.argmax(1).cpu().numpy())
        all_labels.extend(y.numpy())

cm_swin   = confusion_matrix(all_labels, all_preds)
report_swin = classification_report(all_labels, all_preds,
                target_names=class_names, zero_division=0)
print("\n" + report_swin)

# ── Plot ──
short_labels = ["BLB", "HL", "RB", "TU"]
fig, ax = plt.subplots(figsize=(6, 5))
sns.heatmap(cm_swin, annot=True, fmt='d', cmap='Blues',
            xticklabels=short_labels, yticklabels=short_labels,
            ax=ax, annot_kws={"size": 12}, linewidths=0.5)
ax.set_title(f"Confusion Matrix — {swin_name}\n(Test Acc: {swin_acc:.4f})",
             fontsize=12, fontweight='bold', pad=10)
ax.set_xlabel("Predicted", fontsize=10)
ax.set_ylabel("Actual",    fontsize=10)
ax.tick_params(axis='x', labelsize=9)
ax.tick_params(axis='y', labelsize=9, rotation=0)
plt.figtext(0.5, 0.01,
    "BLB=Bacterial Leaf Blight | HL=Healthy Leaf | RB=Rice Blast | TU=Tungro",
    ha='center', fontsize=8, style='italic')
plt.tight_layout()
base = os.path.join(OUT_DIR, "plots", f"confusion_matrix_{swin_name.replace(' ','_')}")
fig.savefig(base+".png", dpi=300, bbox_inches="tight")
fig.savefig(base+".pdf",           bbox_inches="tight")
print(f"\n  saved -> {base}.png")
plt.show()
# Out:
#                        precision    recall  f1-score   support
#
# Bacterial Leaf Blight       0.71      0.96      0.81        98
#         Healthy _leaf       0.94      1.00      0.97       137
#            Rice Blast       0.99      0.85      0.91       335
#                Tungro       0.96      0.97      0.97       374
#
#              accuracy                           0.93       944
#             macro avg       0.90      0.95      0.92       944
#          weighted avg       0.94      0.93      0.93       944
#
#
#   saved -> /kaggle/working/paper_outputs/plots/confusion_matrix_Swin-Tiny.png

# %%
import os, math
import numpy as np
import torch
import matplotlib.pyplot as plt

from pytorch_grad_cam import GradCAM
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget
from pytorch_grad_cam.utils.image import show_cam_on_image

# ── Normalization reverse (ImageNet)
inv_mean = np.array([0.485, 0.456, 0.406])
inv_std  = np.array([0.229, 0.224, 0.225])

def denormalize(t):
    img = t.permute(1, 2, 0).cpu().numpy()
    return np.clip(img * inv_std + inv_mean, 0, 1)

def get_pred(model, img):
    model.eval()
    with torch.no_grad():
        return model(img.unsqueeze(0).to(device)).argmax(1).item()

# ── ✅ FIX: Lazy evaluation using lambda
target_layers_map = {
    "MobileNetV3-Large": lambda m: [m.features[-2]],   # better than [-1]
    "EfficientNetB0":    lambda m: [m.features[-1]],
    "ResNet18":          lambda m: [m.layer4[-1]],
    "DenseNet121":       lambda m: [m.features[-1]],
    "ViT-Tiny":          lambda m: [m.blocks[-1].norm1],
    "Swin-Tiny":         lambda m: [m.backbone.norm],
}

# ── Reshape functions (for transformers)
def reshape_vit(tensor, H=14, W=14):
    tensor = tensor[:, 1:, :]
    return tensor.reshape(tensor.size(0), H, W, tensor.size(2)).permute(0,3,1,2)

def reshape_swin(tensor):
    if tensor.dim() == 4:
        return tensor.permute(0,3,1,2)
    B, L, C = tensor.shape
    H = W = int(math.sqrt(L))
    if H * W != L:
        return tensor.permute(0,2,1).unsqueeze(2)
    return tensor.reshape(B, H, W, C).permute(0,3,1,2)

reshape_map = {
    "ViT-Tiny":  reshape_vit,
    "Swin-Tiny": reshape_swin,
}

# ── Select correct target layer
target_layers = target_layers_map[best_name](best_model)

# ── Find 1 correct sample per class
print(f"Generating Grad-CAM for: {best_name}")
print("Finding representative samples ...")

best_model.eval()
seen = {}

for idx in range(len(test_ds)):
    img, label = test_ds[idx]

    if label in seen:
        continue

    if get_pred(best_model, img) == label:
        seen[label] = idx

    if len(seen) == num_classes:
        break

sample_indices = [seen[c] for c in sorted(seen.keys())]

print("Classes found:",
      [class_names[test_ds[i][1]] for i in sample_indices])

# ── Plot setup
n_cols = len(sample_indices)
fig, axes = plt.subplots(2, n_cols, figsize=(n_cols * 3, 6))

# ── Grad-CAM init
cam = GradCAM(
    model=best_model,
    target_layers=target_layers,
    reshape_transform=reshape_map.get(best_name, None)
)

# ── Generate visualizations
for ci, idx in enumerate(sample_indices):
    img, label = test_ds[idx]

    rgb  = denormalize(img)
    pred = get_pred(best_model, img)

    # Row 1: Original
    axes[0, ci].imshow(rgb)
    axes[0, ci].set_title(class_names[label],
                          fontsize=10,
                          fontweight='bold',
                          pad=4)
    axes[0, ci].axis('off')

    if ci == 0:
        axes[0, ci].set_ylabel("Original",
                               fontsize=9,
                               fontweight='bold')

    # Row 2: Grad-CAM
    grayscale = cam(
        input_tensor=img.unsqueeze(0).to(device),
        targets=[ClassifierOutputTarget(pred)]
    )[0]

    cam_img = show_cam_on_image(rgb, grayscale, use_rgb=True)

    axes[1, ci].imshow(cam_img)
    axes[1, ci].axis('off')

    color = 'green' if pred == label else 'red'

    axes[1, ci].set_xlabel(
        f"Pred: {class_names[pred]}",
        fontsize=9,
        color=color,
        fontweight='bold',
        labelpad=3
    )

    if ci == 0:
        axes[1, ci].set_ylabel("Grad-CAM",
                               fontsize=9,
                               fontweight='bold')

# ── Titles and saving
plt.suptitle(
    f"Grad-CAM — {best_name}",
    fontsize=12,
    fontweight='bold',
    y=1.02
)

plt.figtext(
    0.5, -0.02,
    "BLB=Bacterial Leaf Blight | HL=Healthy Leaf | RB=Rice Blast | TU=Tungro\n"
    "xlabel color: green=correct | red=misclassified",
    ha='center',
    fontsize=8,
    style='italic'
)

plt.tight_layout()

# ── Save output
base = os.path.join(
    OUT_DIR,
    "gradcam",
    f"gradcam_best_{best_name.replace(' ', '_')}"
)

os.makedirs(os.path.dirname(base), exist_ok=True)

fig.savefig(base + ".png", dpi=300, bbox_inches="tight")
fig.savefig(base + ".pdf", bbox_inches="tight")

print(f"\n  saved -> {base}.png")

plt.show()

print("\n✅ Grad-CAM (best model) saved.")
# Out:
# Generating Grad-CAM for: MobileNetV3-Large
# Finding representative samples ...
# Classes found: ['Bacterial Leaf Blight', 'Healthy _leaf', 'Rice Blast', 'Tungro']
#
#   saved -> /kaggle/working/paper_outputs/gradcam/gradcam_best_MobileNetV3-Large.png
# ✅ Grad-CAM (best model) saved.

# %%
# ── Swin-Tiny Grad-CAM ──
swin_name  = "Swin-Tiny"
swin_model = all_models[swin_name]

target_layers_swin = target_layers_map[swin_name](swin_model)

print(f"Generating Grad-CAM for: {swin_name}")
print("Finding representative samples ...")

swin_model.eval()
seen = {}

for idx in range(len(test_ds)):
    img, label = test_ds[idx]
    if label in seen:
        continue
    if get_pred(swin_model, img) == label:
        seen[label] = idx
    if len(seen) == num_classes:
        break

sample_indices = [seen[c] for c in sorted(seen.keys())]
print("Classes found:", [class_names[test_ds[i][1]] for i in sample_indices])

# ── Plot setup
n_cols = len(sample_indices)
fig, axes = plt.subplots(2, n_cols, figsize=(n_cols * 3, 6))

# ── Grad-CAM init
cam_swin = GradCAM(
    model=swin_model,
    target_layers=target_layers_swin,
    reshape_transform=reshape_map.get(swin_name, None)
)

# ── Generate visualizations
for ci, idx in enumerate(sample_indices):
    img, label = test_ds[idx]
    rgb  = denormalize(img)
    pred = get_pred(swin_model, img)

    # Row 1: Original
    axes[0, ci].imshow(rgb)
    axes[0, ci].set_title(class_names[label], fontsize=10,
                          fontweight='bold', pad=4)
    axes[0, ci].axis('off')
    if ci == 0:
        axes[0, ci].set_ylabel("Original", fontsize=9, fontweight='bold')

    # Row 2: Grad-CAM
    grayscale = cam_swin(
        input_tensor=img.unsqueeze(0).to(device),
        targets=[ClassifierOutputTarget(pred)]
    )[0]

    cam_img = show_cam_on_image(rgb, grayscale, use_rgb=True)
    axes[1, ci].imshow(cam_img)
    axes[1, ci].axis('off')

    color = 'green' if pred == label else 'red'
    axes[1, ci].set_xlabel(f"Pred: {class_names[pred]}", fontsize=9,
                           color=color, fontweight='bold', labelpad=3)
    if ci == 0:
        axes[1, ci].set_ylabel("Grad-CAM", fontsize=9, fontweight='bold')

plt.suptitle(f"Grad-CAM — {swin_name}", fontsize=12,
             fontweight='bold', y=1.02)
plt.figtext(0.5, -0.02,
    "BLB=Bacterial Leaf Blight | HL=Healthy Leaf | RB=Rice Blast | TU=Tungro\n"
    "xlabel color: green=correct | red=misclassified",
    ha='center', fontsize=8, style='italic')
plt.tight_layout()

base = os.path.join(OUT_DIR, "gradcam",
                    f"gradcam_{swin_name.replace(' ', '_')}")
os.makedirs(os.path.dirname(base), exist_ok=True)
fig.savefig(base + ".png", dpi=300, bbox_inches="tight")
fig.savefig(base + ".pdf", bbox_inches="tight")
print(f"\n  saved -> {base}.png")
plt.show()
print("\n✅ Grad-CAM (Swin-Tiny) saved.")
# Out:
# Generating Grad-CAM for: Swin-Tiny
# Finding representative samples ...
# Classes found: ['Bacterial Leaf Blight', 'Healthy _leaf', 'Rice Blast', 'Tungro']
#
#   saved -> /kaggle/working/paper_outputs/gradcam/gradcam_Swin-Tiny.png
# ✅ Grad-CAM (Swin-Tiny) saved.

# %%
import time

# ── Measure latency for all models (100 forward passes, batch=1)
def measure_latency(model, device, n=100):
    model.eval()
    x = torch.randn(1, 3, 224, 224).to(device)
    with torch.inference_mode():
        for _ in range(10): model(x)          # warmup
        if device == "cuda": torch.cuda.synchronize()
        t0 = time.perf_counter()
        for _ in range(n): model(x)
        if device == "cuda": torch.cuda.synchronize()
        elapsed = time.perf_counter() - t0
    return (elapsed / n) * 1000              # ms per image

model_names_ordered = [
    "MobileNetV3-Large", "EfficientNetB0", "ResNet18",
    "DenseNet121", "ViT-Tiny", "Swin-Tiny"
]
model_list = [
    model_mobilenet, model_eff, model_resnet,
    model_densenet,  model_vit, model_swin
]

latencies = []
print("Measuring latency (ms/image) ...")
for name, model in zip(model_names_ordered, model_list):
    lat = measure_latency(model, device)
    latencies.append(lat)
    print(f"  {name:<20} {lat:.2f} ms")

# ── Bar chart
fig, ax = plt.subplots(figsize=(8, 5))
colors = ['#e07b54' if n == best_name else '#5b8dd9' for n in model_names_ordered]
bars   = ax.bar(model_names_ordered, latencies, color=colors, width=0.55, edgecolor='white')
ax.bar_label(bars, fmt='%.2f ms', fontsize=9, padding=4)

# Highlight best model in legend
from matplotlib.patches import Patch
legend_elements = [
    Patch(facecolor='#e07b54', label=f'Best model ({best_name})'),
    Patch(facecolor='#5b8dd9', label='Other models')
]
ax.legend(handles=legend_elements, fontsize=9, loc='upper left')

ax.set_ylabel("Latency (ms / image)", fontsize=10)
ax.set_title("Inference Latency — All Models", fontsize=12, fontweight='bold')
ax.set_ylim(0, max(latencies) * 1.25)
ax.tick_params(axis='x', rotation=15, labelsize=9)
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()

base = os.path.join(OUT_DIR, "plots", "latency_all_models")
fig.savefig(base+".png", dpi=300, bbox_inches="tight")
fig.savefig(base+".pdf",           bbox_inches="tight")
print(f"\n  saved -> {base}.png")
plt.show()
print("\n✅ Latency chart saved.")
# Out:
# Measuring latency (ms/image) ...
#   MobileNetV3-Large    6.07 ms
#   EfficientNetB0       8.02 ms
#   ResNet18             2.78 ms
#   DenseNet121          14.59 ms
#   ViT-Tiny             4.56 ms
#   Swin-Tiny            10.27 ms
#
#   saved -> /kaggle/working/paper_outputs/plots/latency_all_models.png
# ✅ Latency chart saved.

# %%
# ── Loss Curves for All Models
import matplotlib.pyplot as plt

loss_data = {
    "MobileNetV3-Large": (mobilenet_train_losses, mobilenet_val_losses),
    "EfficientNetB0":    (eff_train_losses,        eff_val_losses),
    "ResNet18":          (resnet_train_losses,      resnet_val_losses),
    "DenseNet121":       (densenet_train_losses,    densenet_val_losses),
    "ViT-Tiny":          (vit_train_losses,         vit_val_losses),
    "Swin-Tiny":         (swin_train_losses,        swin_val_losses),
}

colors = ['#2196F3', '#4CAF50', '#FF9800', '#9C27B0', '#F44336', '#00BCD4']

fig, axes = plt.subplots(2, 3, figsize=(15, 9))
axes = axes.flatten()

for idx, (name, (train_l, val_l)) in enumerate(loss_data.items()):
    ax = axes[idx]
    epochs = range(1, len(train_l) + 1)
    ax.plot(epochs, train_l, label='Train Loss', color=colors[idx], linewidth=2)
    ax.plot(epochs, val_l,   label='Val Loss',   color=colors[idx], linewidth=2,
            linestyle='--', alpha=0.7)
    ax.set_title(name, fontsize=11, fontweight='bold')
    ax.set_xlabel("Epoch", fontsize=9)
    ax.set_ylabel("Loss",  fontsize=9)
    ax.legend(fontsize=8)
    ax.grid(alpha=0.3)
    best_val = min(val_l)
    ax.axhline(y=best_val, color='gray', linestyle=':', alpha=0.5)
    ax.annotate(f'Best: {best_val:.4f}',
                xy=(val_l.index(best_val)+1, best_val),
                fontsize=7, color='gray',
                xytext=(5, 5), textcoords='offset points')

plt.suptitle("Training & Validation Loss — All Models", fontsize=14, fontweight='bold', y=1.01)
plt.tight_layout()

save_path = os.path.join(OUT_DIR, "plots", "all_loss_curves")
fig.savefig(save_path + ".png", dpi=300, bbox_inches="tight")
fig.savefig(save_path + ".pdf",           bbox_inches="tight")
print(f"Saved -> {save_path}.png")
plt.show()
# Out:
# Saved -> /kaggle/working/paper_outputs/plots/all_loss_curves.png

# %%
# ── Qualitative Analysis — Publication Table Style
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import torch

mpl.rcParams['font.family'] = 'DejaVu Serif'

inv_mean = np.array([0.485, 0.456, 0.406])
inv_std  = np.array([0.229, 0.224, 0.225])

def denormalize(t):
    img = t.permute(1, 2, 0).cpu().numpy()
    return np.clip(img * inv_std + inv_mean, 0, 1)

label_map = {
    "Bacterial Leaf Blight": "Bacterial Leaf Blight",
    "Healthy _leaf":         "Healthy Leaf",
    "Rice Blast":            "Rice Blast",
    "Tungro":                "Tungro",
}

# ── best_model 
best_name  = max(all_model_metrics, key=lambda k: all_model_metrics[k]["accuracy"])
best_model = all_models[best_name]
print(f"Best model: {best_name}")

# ── Sample collection
best_model.eval()
correct_samples, incorrect_samples = [], []
seen_correct, seen_incorrect = set(), set()

with torch.no_grad():
    for idx in range(len(test_ds)):
        img, label = test_ds[idx]
        out = best_model(img.unsqueeze(0).to(device))
        if out.dim() == 4: out = out.mean(dim=[2,3])
        if out.dim() != 2: out = out.view(out.size(0), -1)
        prob = torch.softmax(out, dim=1)
        pred = out.argmax(1).item()
        conf = prob.max().item()

        if pred == label and label not in seen_correct and len(correct_samples) < 3:
            correct_samples.append((img.cpu(), label, pred, conf))
            seen_correct.add(label)
        elif pred != label and label not in seen_incorrect and len(incorrect_samples) < 3:
            incorrect_samples.append((img.cpu(), label, pred, conf))
            seen_incorrect.add(label)

        if len(correct_samples) >= 3 and len(incorrect_samples) >= 3:
            break

print(f"Correct: {len(correct_samples)} | Incorrect: {len(incorrect_samples)}")

# ── Interleave
chosen = []
for pair in zip(correct_samples, incorrect_samples):
    chosen.extend(pair)
if len(chosen) < 4:
    chosen = correct_samples + incorrect_samples
chosen = chosen[:6]
n = len(chosen)

# ── Layout
ROW_H        = 1.8
FIG_H        = ROW_H * n + 1.2
TOP_MARGIN   = 0.9
HEADER_H     = 0.55
IMG_H_IN     = 1.1
IMG_W_FRAC   = 0.13

col_img    = 0.03
col_desc   = 0.20
col_actual = 0.58
col_pred   = 0.78
col_conf   = 0.93

fig = plt.figure(figsize=(11, FIG_H), facecolor='white')

def yf(inches): return 1.0 - inches / FIG_H

# top rule
fig.add_artist(plt.Line2D([0.02,0.98],[yf(TOP_MARGIN)]*2,
    transform=fig.transFigure, color='black', linewidth=1.5))

# header
hy = yf(TOP_MARGIN + HEADER_H * 0.5)
for col, txt, ha in [
    (col_desc,   "Image Sample", 'left'),
    (col_actual, "Actual",       'center'),
    (col_pred,   "Predicted",    'center'),
    (col_conf,   "Conf.",        'center'),
]:
    fig.text(col, hy, txt, fontsize=10, fontweight='bold',
             ha=ha, va='center', transform=fig.transFigure)

# header rule
fig.add_artist(plt.Line2D([0.02,0.98],[yf(TOP_MARGIN+HEADER_H)]*2,
    transform=fig.transFigure, color='black', linewidth=1.0))

# rows
for ri, (img, actual, pred, conf) in enumerate(chosen):
    rtop   = TOP_MARGIN + HEADER_H + ri * ROW_H
    rcen   = rtop + ROW_H * 0.5
    rbot   = rtop + ROW_H
    rcen_f = yf(rcen)

    actual_name = label_map.get(class_names[actual], class_names[actual])
    pred_name   = label_map.get(class_names[pred],   class_names[pred])
    ok          = (actual == pred)
    clr         = '#1a6e1a' if ok else '#aa1111'

    # image
    ih_frac = IMG_H_IN / FIG_H
    ax_img  = fig.add_axes([col_img, yf(rcen + IMG_H_IN*0.5), IMG_W_FRAC, ih_frac])
    ax_img.imshow(denormalize(img))
    ax_img.set_xticks([]); ax_img.set_yticks([])
    for sp in ax_img.spines.values():
        sp.set_visible(True); sp.set_edgecolor(clr); sp.set_linewidth(2.0)

    # text
    fig.text(col_desc, rcen_f + 0.022,
             f"Sample {ri+1}.  {class_names[actual].replace('Healthy _leaf','Healthy Leaf')}",
             fontsize=9.5, fontweight='bold', ha='left', va='center',
             transform=fig.transFigure, color='#111111')
    fig.text(col_desc, rcen_f - 0.022,
             "Correctly classified" if ok else "Misclassified",
             fontsize=8.5, ha='left', va='center', style='italic',
             transform=fig.transFigure, color=clr)
    fig.text(col_actual, rcen_f, actual_name,
             fontsize=9, ha='center', va='center',
             transform=fig.transFigure, color='#222222')
    fig.text(col_pred, rcen_f, pred_name,
             fontsize=9, ha='center', va='center', fontweight='bold',
             transform=fig.transFigure, color=clr)
    fig.text(col_conf, rcen_f, f"{conf:.1%}",
             fontsize=9, ha='center', va='center',
             transform=fig.transFigure, color=clr)

    # row separator
    lw = 1.2 if ri == n-1 else 0.5
    cs = 'black' if ri == n-1 else '#aaaaaa'
    fig.add_artist(plt.Line2D([0.02,0.98],[yf(rbot)]*2,
        transform=fig.transFigure, color=cs, linewidth=lw))

fig.suptitle(
    f"Qualitative Analysis — {best_name}  "
    "| Green = Correct   Red = Misclassified",
    fontsize=10, fontweight='bold', y=yf(0.35)
)
plt.subplots_adjust(top=1, bottom=0, left=0, right=1)

save_path = os.path.join(OUT_DIR, "plots", "qualitative_table_publication")
os.makedirs(os.path.dirname(save_path), exist_ok=True)
fig.savefig(save_path + ".png", dpi=300, bbox_inches="tight")
fig.savefig(save_path + ".pdf",           bbox_inches="tight")
print(f"✅ Saved -> {save_path}.png / .pdf")
plt.show()
# Out:
# Best model: MobileNetV3-Large
# Correct: 3 | Incorrect: 3
# ✅ Saved -> /kaggle/working/paper_outputs/plots/qualitative_table_publication.png / .pdf

# %%
# ── Qualitative Analysis — Swin-Tiny ──
swin_name  = "Swin-Tiny"
swin_model = all_models[swin_name]
print(f"Model: {swin_name}")

# ── Sample collection
swin_model.eval()
correct_samples, incorrect_samples = [], []
seen_correct, seen_incorrect = set(), set()

with torch.no_grad():
    for idx in range(len(test_ds)):
        img, label = test_ds[idx]
        out = swin_model(img.unsqueeze(0).to(device))
        if out.dim() == 4: out = out.mean(dim=[2,3])
        if out.dim() != 2: out = out.view(out.size(0), -1)
        prob = torch.softmax(out, dim=1)
        pred = out.argmax(1).item()
        conf = prob.max().item()

        if pred == label and label not in seen_correct and len(correct_samples) < 3:
            correct_samples.append((img.cpu(), label, pred, conf))
            seen_correct.add(label)
        elif pred != label and label not in seen_incorrect and len(incorrect_samples) < 3:
            incorrect_samples.append((img.cpu(), label, pred, conf))
            seen_incorrect.add(label)

        if len(correct_samples) >= 3 and len(incorrect_samples) >= 3:
            break

print(f"Correct: {len(correct_samples)} | Incorrect: {len(incorrect_samples)}")

# ── Interleave
chosen = []
for pair in zip(correct_samples, incorrect_samples):
    chosen.extend(pair)
if len(chosen) < 4:
    chosen = correct_samples + incorrect_samples
chosen = chosen[:6]
n = len(chosen)

# ── Layout
ROW_H        = 1.8
FIG_H        = ROW_H * n + 1.2
TOP_MARGIN   = 0.9
HEADER_H     = 0.55
IMG_H_IN     = 1.1
IMG_W_FRAC   = 0.13

col_img    = 0.03
col_desc   = 0.20
col_actual = 0.58
col_pred   = 0.78
col_conf   = 0.93

fig = plt.figure(figsize=(11, FIG_H), facecolor='white')

def yf(inches): return 1.0 - inches / FIG_H

fig.add_artist(plt.Line2D([0.02,0.98],[yf(TOP_MARGIN)]*2,
    transform=fig.transFigure, color='black', linewidth=1.5))

hy = yf(TOP_MARGIN + HEADER_H * 0.5)
for col, txt, ha in [
    (col_desc,   "Image Sample", 'left'),
    (col_actual, "Actual",       'center'),
    (col_pred,   "Predicted",    'center'),
    (col_conf,   "Conf.",        'center'),
]:
    fig.text(col, hy, txt, fontsize=10, fontweight='bold',
             ha=ha, va='center', transform=fig.transFigure)

fig.add_artist(plt.Line2D([0.02,0.98],[yf(TOP_MARGIN+HEADER_H)]*2,
    transform=fig.transFigure, color='black', linewidth=1.0))

for ri, (img, actual, pred, conf) in enumerate(chosen):
    rtop   = TOP_MARGIN + HEADER_H + ri * ROW_H
    rcen   = rtop + ROW_H * 0.5
    rbot   = rtop + ROW_H
    rcen_f = yf(rcen)

    actual_name = label_map.get(class_names[actual], class_names[actual])
    pred_name   = label_map.get(class_names[pred],   class_names[pred])
    ok          = (actual == pred)
    clr         = '#1a6e1a' if ok else '#aa1111'

    ih_frac = IMG_H_IN / FIG_H
    ax_img  = fig.add_axes([col_img, yf(rcen + IMG_H_IN*0.5), IMG_W_FRAC, ih_frac])
    ax_img.imshow(denormalize(img))
    ax_img.set_xticks([]); ax_img.set_yticks([])
    for sp in ax_img.spines.values():
        sp.set_visible(True); sp.set_edgecolor(clr); sp.set_linewidth(2.0)

    fig.text(col_desc, rcen_f + 0.022,
             f"Sample {ri+1}.  {class_names[actual].replace('Healthy _leaf','Healthy Leaf')}",
             fontsize=9.5, fontweight='bold', ha='left', va='center',
             transform=fig.transFigure, color='#111111')
    fig.text(col_desc, rcen_f - 0.022,
             "Correctly classified" if ok else "Misclassified",
             fontsize=8.5, ha='left', va='center', style='italic',
             transform=fig.transFigure, color=clr)
    fig.text(col_actual, rcen_f, actual_name,
             fontsize=9, ha='center', va='center',
             transform=fig.transFigure, color='#222222')
    fig.text(col_pred, rcen_f, pred_name,
             fontsize=9, ha='center', va='center', fontweight='bold',
             transform=fig.transFigure, color=clr)
    fig.text(col_conf, rcen_f, f"{conf:.1%}",
             fontsize=9, ha='center', va='center',
             transform=fig.transFigure, color=clr)

    lw = 1.2 if ri == n-1 else 0.5
    cs = 'black' if ri == n-1 else '#aaaaaa'
    fig.add_artist(plt.Line2D([0.02,0.98],[yf(rbot)]*2,
        transform=fig.transFigure, color=cs, linewidth=lw))

fig.suptitle(
    f"Qualitative Analysis — {swin_name}  "
    "| Green = Correct   Red = Misclassified",
    fontsize=10, fontweight='bold', y=yf(0.35)
)
plt.subplots_adjust(top=1, bottom=0, left=0, right=1)

save_path = os.path.join(OUT_DIR, "plots", "qualitative_table_swin_tiny")
os.makedirs(os.path.dirname(save_path), exist_ok=True)
fig.savefig(save_path + ".png", dpi=300, bbox_inches="tight")
fig.savefig(save_path + ".pdf",           bbox_inches="tight")
print(f"✅ Saved -> {save_path}.png / .pdf")
plt.show()
# Out:
# Model: Swin-Tiny
# Correct: 3 | Incorrect: 3
# ✅ Saved -> /kaggle/working/paper_outputs/plots/qualitative_table_swin_tiny.png / .pdf

# %%
# ── Verify all outputs saved as both PNG + PDF
import glob, os
from PIL import Image

dirs = [
    os.path.join(OUT_DIR, "plots"),
    os.path.join(OUT_DIR, "gradcam"),
]

print("📁 Converting any missing PDFs...\n")
converted = 0
for d in dirs:
    for png in glob.glob(os.path.join(d, "*.png")):
        pdf = png.replace(".png", ".pdf")
        if not os.path.exists(pdf):
            Image.open(png).convert("RGB").save(pdf, "PDF", resolution=300)
            print(f"  Converted: {os.path.basename(pdf)}")
            converted += 1

if converted == 0:
    print("  ✅ all files saved in pdf।")

print("\n📋 Final output list:")
print(f"{'File':<55} {'KB':>8}")
print("-" * 65)
for d in dirs:
    for f in sorted(glob.glob(os.path.join(d, "*"))):
        kb = os.path.getsize(f) / 1024
        print(f"  {os.path.relpath(f, OUT_DIR):<53} {kb:>7.1f}")
# Out:
# 📁 Converting any missing PDFs...
#
#   ✅ all files saved in pdf।
#
# 📋 Final output list:
# File                                                          KB
# -----------------------------------------------------------------
#   plots/all_loss_curves.pdf                                31.2
#   plots/all_loss_curves.png                               542.1
#   plots/confusion_matrix_Swin-Tiny.pdf                     32.5
#   plots/confusion_matrix_Swin-Tiny.png                    111.8
#   plots/confusion_matrix_best_MobileNetV3-Large.pdf        32.9
#   plots/confusion_matrix_best_MobileNetV3-Large.png       117.0
#   plots/latency_all_models.pdf                             23.5
#   plots/latency_all_models.png                            169.1
#   plots/qualitative_table_publication.pdf                 108.4
#   plots/qualitative_table_publication.png                 805.5
#   plots/qualitative_table_swin_tiny.pdf                   102.2
#   plots/qualitative_table_swin_tiny.png                   759.2
#   gradcam/gradcam_Swin-Tiny.pdf                           422.4
#   gradcam/gradcam_Swin-Tiny.png                           739.0
#   gradcam/gradcam_best_MobileNetV3-Large.pdf              396.4
#   gradcam/gradcam_best_MobileNetV3-Large.png              713.0

# %%
from sklearn.metrics import f1_score

val_macro_f1  = {}
test_macro_f1 = {}

for name, model in all_models.items():
    model.eval()
    
    # ── Val Macro F1
    val_preds, val_labels = [], []
    with torch.no_grad():
        for x, y in val_loader:
            x = x.to(device)
            out = model(x)
            if out.dim()==4: out = out.mean(dim=[2,3])
            if out.dim()!=2: out = out.view(out.size(0),-1)
            val_preds.extend(out.argmax(1).cpu().numpy())
            val_labels.extend(y.numpy())
    val_macro_f1[name] = f1_score(val_labels, val_preds, average='macro')
    
    # ── Test Macro F1 (already in all_model_metrics)
    test_macro_f1[name] = all_model_metrics[name]['macro_f1']

# ── Print Table
print(f"\n{'Model':<22} {'Val F1-M':>10} {'Test F1-M':>10}")
print("-" * 44)
for name in plot_models:
    print(f"{name:<22} {val_macro_f1[name]:>10.4f} {test_macro_f1[name]:>10.4f}")
# Out:
# Model                    Val F1-M  Test F1-M
# --------------------------------------------
# MobileNetV3-Large          0.8977     0.9161
# EfficientNetB0             0.8772     0.8975
# ResNet18                   0.8238     0.8388
# DenseNet121                0.7500     0.7582
# ViT-Tiny                   0.8396     0.8230
# Swin-Tiny                  0.8971     0.9158
